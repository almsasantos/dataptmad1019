# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
# !conda install requests
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0"}

# %%
# Your code

response = requests.get(url, headers=headers)
results = response.json()
results
# Out:
# {'total_count': 26146,
#  'pagination': {'page_count': 312, 'current_page': 2, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'NI116D04M-Q11',
#    'name': 'COURT BOROUGH MID WINTERIZED  - Chaussures premiers pas - black/white',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '34,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#    'url_key': 'nike-sportswear-court-borough-mid-winterized-baskets-montantes-blackwhite-ni116d04m-q11',
#    'media': [{'path': 'NI/11/6D/04/MQ/11/NI116D04M-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'GP024K05M-C11',
#    'name': 'BOYS ACTIVE ARCH  - Sweat à capuche - light heather grey',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '20,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4-5a', '6-7a', '8-9a', '10-11a', '12-13a'],
#    'url_key': 'gap-boys-active-arch-sweatshirt-gp024k05m-c11',
#    'media': [{'path': 'GP/02/4K/05/MC/11/GP024K05M-C11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'GAP',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'NI114D03N-M11',
#    'name': 'MD RUNNER 2 - Baskets basses - sequoia/olive canvas/sail/wolf grey',
#    'price': {'original': '37,95\xa0€',
#     'promotional': '28,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '28.5', '29.5', '30', '31.5', '32', '33.5', '34', '35'],
#    'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d03n-m11',
#    'media': [{'path': 'NI/11/4D/03/NM/11/NI114D03N-M11@18.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'CO414D07T-B11',
#    'name': 'CHUCK TAYLOR ALL STAR ON MARS - Baskets montantes - wheat/pale wheat/birch bark',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '32,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['18', '19', '20', '21', '22', '23', '24'],
#    'url_key': 'converse-chuck-taylor-all-star-on-mars-baskets-montantes-wheatpale-wheatbirch-bark-co414d07t-b11',
#    'media': [{'path': 'CO/41/4D/07/TB/11/CO414D07T-B11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'NI113D08C-Q11',
#    'name': 'RENEW LUCENT - Mocassins - black/white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26'],
#    'url_key': 'nike-sportswear-renew-lucent-baskets-basses-blackwhite-ni113d08c-q11',
#    'media': [{'path': 'NI/11/3D/08/CQ/11/NI113D08C-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D07O-Q15',
#    'name': 'AIR MAX 97 - Baskets basses - black/metallic gold',
#    'price': {'original': '139,95\xa0€',
#     'promotional': '83,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-max-97-baskets-basses-ni114d07o-q15',
#    'media': [{'path': 'NI/11/4D/07/OQ/15/NI114D07O-Q15@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'LA224G01L-E15',
#    'name': 'T-shirt basique - midday yellow',
#    'price': {'original': '27,95\xa0€',
#     'promotional': '16,75\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3y', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'lacoste-t-shirt-basique-midday-yellow-la224g01l-e15',
#    'media': [{'path': 'LA/22/4G/01/LE/15/LA224G01L-E15@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'GP053M03G-A11',
#    'name': 'TODDLER GIRL BEAR - Écharpe - ivory frost',
#    'price': {'original': '15,95\xa0€',
#     'promotional': '13,55\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'gap-toddler-girl-bear-echarpe-ivory-frost-gp053m03g-a11',
#    'media': [{'path': 'GP/05/3M/03/GA/11/GP053M03G-A11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'GAP',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'NI113D07T-A11',
#    'name': 'AIR MAX 200 - Baskets basses - white/black/hyper pink/photo blue',
#    'price': {'original': '104,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36.5', '37.5', '38', '38.5'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-whiteblackhyper-pinkphoto-blue-ni113d07t-a11',
#    'media': [{'path': 'NI/11/3D/07/TA/11/NI113D07T-A11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'AD116D0N6-A11',
#    'name': 'CONTINENTAL 80 - Baskets basses - offwhite/true pink/hi res aqua',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '32,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '29', '30', '31', '32', '33', '34'],
#    'url_key': 'adidas-originals-continental-80-baskets-basses-ad116d0n6-a11',
#    'media': [{'path': 'AD/11/6D/0N/6A/11/AD116D0N6-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D0M5-K11',
#    'name': 'FOREST GROVE - Baskets basses - legend marine/collegiate burgundy',
#    'price': {'original': '48,95\xa0€',
#     'promotional': '26,85\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '30', '31', '32', '34', '35'],
#    'url_key': 'adidas-originals-forest-grove-baskets-basses-ad116d0m5-k11',
#    'media': [{'path': 'AD/11/6D/0M/5K/11/AD116D0M5-K11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA224G045-C11',
#    'name': 'BOY TEE - T-shirt imprimé - silver chine',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '24,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'lacoste-boy-tee-t-shirt-imprime-silver-chine-la224g045-c11',
#    'media': [{'path': 'LA/22/4G/04/5C/11/LA224G045-C11@23.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'CJ223F06O-J11',
#    'name': 'GIRL DRESSY BABY - Robe de soirée - pink',
#    'price': {'original': '32,95\xa0€',
#     'promotional': '21,35\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3m', '6m', '9m', '12m', '18m', '24m'],
#    'url_key': 'carters-girl-dressy-baby-robe-de-soiree-pink-cj223f06o-j11',
#    'media': [{'path': 'CJ/22/3F/06/OJ/11/CJ223F06O-J11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Carter's",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114F009-A12',
#    'name': 'Baskets basses - white/black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '47,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['18.5', '19.5', '22', '23.5', '25', '26'],
#    'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni114f009-a12',
#    'media': [{'path': 'NI/11/4F/00/9A/12/NI114F009-A12@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'GP024K05K-G11',
#    'name': 'TODDLER BOY LOGO - Sweat à capuche - red wagon',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '17,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '5a', '12-18m', '18-24m'],
#    'url_key': 'gap-toddler-boy-logo-sweatshirt-red-wagon-gp024k05k-g11',
#    'media': [{'path': 'GP/02/4K/05/KG/11/GP024K05K-G11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'GAP',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'QU124L020-Q11',
#    'name': 'BICHENO BLOOM YOUTH - Veste mi-saison - black',
#    'price': {'original': '129,99\xa0€',
#     'promotional': '64,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '9a', '12a', '14a', '16a'],
#    'url_key': 'quiksilver-bicheno-bloom-youth-veste-dhiver-black-qu124l020-q11',
#    'media': [{'path': 'QU/12/4L/02/0Q/11/QU124L020-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Quiksilver',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'RE016D00T-A11',
#    'name': 'CLASSIC - Chaussures premiers pas - white',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '25,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17',
#     '19.5',
#     '20',
#     '21',
#     '21.5',
#     '22',
#     '23',
#     '23.5',
#     '24',
#     '24.5',
#     '25',
#     '25.5',
#     '26',
#     '26.5'],
#    'url_key': 'reebok-classic-classic-baskets-basses-white-re016d00t-a11',
#    'media': [{'path': 'RE/01/6D/00/TA/11/RE016D00T-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Reebok Classic',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI123D00E-Q11',
#    'name': 'ALL DAY PLAY COVERALL BABY - Combinaison - black',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '24,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['0-3a', '3a', '6a', '9a'],
#    'url_key': 'nike-sportswear-all-day-play-coverall-baby-combinaison-ni123d00e-q11',
#    'media': [{'path': 'NI/12/3D/00/EQ/11/NI123D00E-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI153K002-C11',
#    'name': 'FUTURA HAT AND BOOTIE BABY SET - Bonnet - dark grey heather',
#    'price': {'original': '14,95\xa0€',
#     'promotional': '7,50\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['0-6m'],
#    'url_key': 'nike-sportswear-futura-hat-and-bootie-baby-set-bonnet-ni153k002-c11',
#    'media': [{'path': 'NI/15/3K/00/2C/11/NI153K002-C11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NI114F009-Q13',
#    'name': 'Baskets basses - black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '19.5', '21', '22', '23.5', '27'],
#    'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni114f009-q13',
#    'media': [{'path': 'NI/11/4F/00/9Q/13/NI114F009-Q13@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0AV-A11',
#    'name': 'AIR MAX 200 - Baskets basses - white/black/bright crimson/university gold',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0av-a11',
#    'media': [{'path': 'NI/11/4D/0A/VA/11/NI114D0AV-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA224G014-K13',
#    'name': 'Polo - marine',
#    'price': {'original': '42,95\xa0€',
#     'promotional': '34,35\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3y', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'lacoste-polo-marine-la224g014-k13',
#    'media': [{'path': 'LA/22/4G/01/4K/13/LA224G014-K13@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD126K01A-G11',
#    'name': 'TAPE HOODIE - Sweat à capuche - bordeaux',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '39,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['7-8a'],
#    'url_key': 'adidas-originals-tape-hoodie-sweatshirt-bordeaux-ad126k01a-g11',
#    'media': [{'path': 'AD/12/6K/01/AG/11/AD126K01A-G11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'PO223G063-K11',
#    'name': 'BALL - T-shirt imprimé - french navy',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '39,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL'],
#    'url_key': 'polo-ralph-lauren-ball-polo-french-navy-po223g063-k11',
#    'media': [{'path': 'PO/22/3G/06/3K/11/PO223G063-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Polo Ralph Lauren',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'N1243A0ZC-Q11',
#    'name': "PICO 5 - Chaussures d'entraînement et de fitness - black",
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27.5',
#     '28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-performance-pico-5-chaussures-dentrainement-et-de-fitness-n1243a0zc-q11',
#    'media': [{'path': 'N1/24/3A/0Z/CQ/11/N1243A0ZC-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA224G043-M11',
#    'name': 'PJ9424 - Polo - beeche/silver chine',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '37,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '4a', '5a', '6a', '8a', '12a', '14a', '16a'],
#    'url_key': 'lacoste-long-sleeved-collar-shirt-t-shirt-a-manches-longues-beechesilver-chine-la224g043-m11',
#    'media': [{'path': 'LA/22/4G/04/3M/11/LA224G043-M11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI113F00M-C11',
#    'name': 'AIR MAX AXIS - Mocassins - wolf grey/celestine blue/metallic dark grey/white',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26'],
#    'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni113f00m-c11',
#    'media': [{'path': 'NI/11/3F/00/MC/11/NI113F00M-C11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D0GW-A11',
#    'name': 'CONTINENTAL 80 - Baskets basses - footwear white/scarlet/collegiate navy',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '51,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-continental-80-baskets-basses-ad116d0gw-a11',
#    'media': [{'path': 'AD/11/6D/0G/WA/11/AD116D0GW-A11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': '6MO26G00N-A11',
#    'name': 'MINIME - T-shirt à manches longues - optic white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '33,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '6-9m', '9-12m', '12-18m', '18-24m'],
#    'url_key': 'moschino-minime-t-shirt-a-manches-longues-optic-white-6mo26g00n-a11',
#    'media': [{'path': '6M/O2/6G/00/NA/11/6MO26G00N-A11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'MOSCHINO',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA224K015-K11',
#    'name': 'veste en sweat zippée - navy blue/silver chine',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '64,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3y', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'lacoste-veste-en-sweat-zippee-navy-bluesilver-chine-la224k015-k11',
#    'media': [{'path': 'LA/22/4K/01/5K/11/LA224K015-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'QU124G071-Q11',
#    'name': 'WAVE - T-shirt imprimé - black',
#    'price': {'original': '15,99\xa0€',
#     'promotional': '9,59\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '9a', '12a', '14a', '16a'],
#    'url_key': 'quiksilver-wave-t-shirt-imprime-black-qu124g071-q11',
#    'media': [{'path': 'QU/12/4G/07/1Q/11/QU124G071-Q11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Quiksilver',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'GU123K016-K11',
#    'name': 'Sweatshirt - fancy blue',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '24,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['7a', '8a', '10a', '12a', '16a'],
#    'url_key': 'guess-activewear-core-sweatshirt-gu123k016-k11',
#    'media': [{'path': 'GU/12/3K/01/6K/11/GU123K016-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Guess',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114F00O-Q12',
#    'name': 'Baskets basses - black/hyper violet/gunsmoke/aurora green',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '29,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['19.5', '21', '22', '23.5', '25'],
#    'url_key': 'nike-sportswear-air-max-motion-2-baskets-basses-blackhyper-violetgunsmokeaurora-green-ni114f00o-q12',
#    'media': [{'path': 'NI/11/4F/00/OQ/12/NI114F00O-Q12@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'QU124G072-L11',
#    'name': 'GET BUZZY  - T-shirt imprimé - pastel turquoise',
#    'price': {'original': '17,99\xa0€',
#     'promotional': '8,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '9a', '12a', '14a', '16a'],
#    'url_key': 'quiksilver-get-buzzy-t-shirt-imprime-qu124g072-l11',
#    'media': [{'path': 'QU/12/4G/07/2L/11/QU124G072-L11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Quiksilver',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI123G014-Q11',
#    'name': 'FUTURA STARS TEE - T-shirt à manches longues - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '14,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3-4a', '4-5a', '5-6a', '6-7a'],
#    'url_key': 'nike-sportswear-futura-stars-tee-t-shirt-a-manches-longues-black-ni123g014-q11',
#    'media': [{'path': 'NI/12/3G/01/4Q/11/NI123G014-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D0B7-Q11',
#    'name': 'AIR MAX 97 RFT  - Baskets basses - black/atmosphere grey/gunsmoke',
#    'price': {'original': '144,95\xa0€',
#     'promotional': '86,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-max-97-rft-baskets-basses-blackatmosphere-greygunsmoke-ni114d0b7-q11',
#    'media': [{'path': 'NI/11/4D/0B/7Q/11/NI114D0B7-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI116D04L-K11',
#    'name': 'COURT BOROUGH MID BOOT WINTERIZED - Chaussures de skate - blue void/blue stardust/coast/topaz mist/photo blue',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '38,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '28.5', '29.5', '30', '31.5', '32', '33.5', '34', '35'],
#    'url_key': 'nike-sportswear-court-borough-mid-boot-winterized-baskets-montantes-ni116d04l-k11',
#    'media': [{'path': 'NI/11/6D/04/LK/11/NI116D04L-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'NI126K010-C11',
#    'name': 'CLUB HOODIE - Sweat à capuche - carbon heather',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '22,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2-3a', '4-5a', '5-6a', '6-7a'],
#    'url_key': 'nike-sportswear-club-hoodie-sweatshirt-carbon-heather-ni126k010-c11',
#    'media': [{'path': 'NI/12/6K/01/0C/11/NI126K010-C11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D0BU-C11',
#    'name': 'Baskets basses - platinum tint/black/bright crimson/hyper royal',
#    'price': {'original': '32,95\xa0€',
#     'promotional': '23,05\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#    'url_key': 'nike-sportswear-explore-strada-baskets-basses-ni114d0bu-c11',
#    'media': [{'path': 'NI/11/4D/0B/UC/11/NI114D0BU-C11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'AD116D00A-A11',
#    'name': 'SUPERSTAR - Baskets basses - white/core black',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-superstar-baskets-basses-blanc-ad116d00a-a11',
#    'media': [{'path': 'AD/11/6D/00/AA/11/AD116D00A-A11@18.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116F009-Q11',
#    'name': 'SAMBA - Baskets basses - core black/footwear white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['19', '20', '21', '22', '23', '24', '25', '26', '27'],
#    'url_key': 'adidas-originals-samba-baskets-basses-core-blackfootwear-white-ad116f009-q11',
#    'media': [{'path': 'AD/11/6F/00/9Q/11/AD116F009-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'P0214C008-C11',
#    'name': 'PLAY DESERT - Baskets montantes - terra/taupe',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '53,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['26', '27', '28', '29', '30', '31', '32'],
#    'url_key': 'shoo-pom-play-desert-baskets-montantes-terrataupe-p0214c008-c11',
#    'media': [{'path': 'P0/21/4C/00/8C/11/P0214C008-C11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Shoo Pom',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D07G-A11',
#    'name': 'STAN SMITH CF I - Chaussures premiers pas - white/green',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '39,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['19',
#     '20',
#     '21',
#     '22',
#     '23',
#     '24',
#     '25',
#     '26',
#     '27',
#     '23 1/2',
#     '25 1/2',
#     '26 1/2'],
#    'url_key': 'adidas-originals-stan-smith-cf-i-baskets-basses-whitegreen-ad116d07g-a11',
#    'media': [{'path': 'AD/11/6D/07/GA/11/AD116D07G-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D0O2-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/real pink',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '45,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitereal-pink-ad116d0o2-a11',
#    'media': [{'path': 'AD/11/6D/0O/2A/11/AD116D0O2-A11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI124D00T-K11',
#    'name': 'CHEVRON COVERALL BABY - Combinaison - mountain blue',
#    'price': {'original': '31,95\xa0€',
#     'promotional': '17,55\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['0-3a', '3a', '6a', '9a'],
#    'url_key': 'nike-sportswear-chevron-coverall-baby-combinaison-ni124d00t-k11',
#    'media': [{'path': 'NI/12/4D/00/TK/11/NI124D00T-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE223G03U-M11',
#    'name': 'BATWING TEE - T-shirt à manches longues - tea tree pink',
#    'price': {'original': '21,95\xa0€',
#     'promotional': '18,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '5a', '6a', '10a', '12a', '14a', '16a'],
#    'url_key': 'levisr-batwing-tee-t-shirt-a-manches-longues-le223g03u-m11',
#    'media': [{'path': 'LE/22/3G/03/UM/11/LE223G03U-M11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD124G02W-Q11',
#    'name': 'GRAPHIC TEE - T-shirt imprimé - black',
#    'price': {'original': '22,95\xa0€',
#     'promotional': '11,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['7-8a', '8-9a', '9-10a', '10-11a', '11-12a', '13-14a', '14-15a'],
#    'url_key': 'adidas-originals-graphic-tee-t-shirt-imprime-black-ad124g02w-q11',
#    'media': [{'path': 'AD/12/4G/02/WQ/11/AD124G02W-Q11@14.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO126B004-K11',
#    'name': 'BABY COLORBLOCK  - Pantalon classique - black iris/multi',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['1-2m', '2-4m', '4-6m', '6-9m', '9-12m', '12-18m', '18-24m'],
#    'url_key': 'tommy-hilfiger-baby-colorblock-pantalon-classique-black-irismulti-to126b004-k11',
#    'media': [{'path': 'TO/12/6B/00/4K/11/TO126B004-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D0AT-A11',
#    'name': 'AIR MAX 200 - Baskets basses - white/black/bright crimson/university gold',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-whiteblackbright-crimsonuniversity-gold-ni114d0at-a11',
#    'media': [{'path': 'NI/11/4D/0A/TA/11/NI114D0AT-A11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
# ...
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'BUSINESS', 'label': 'business'},
#     {'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'OCTOBER_FEST', 'label': 'festival de la bière'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'BRIDAL', 'label': 'Looks de mariée'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'fr_aw19_fresh_days_2019_49', 'label': '-20% EXTRA'},
#     {'key': 'kids_comics_cartoons', 'label': 'BD et dessins animés'},
#     {'key': 'kids_sneaker_releases', 'label': 'Hot Sneaker Drops'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]}],
#  'total_article_count': 26144,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promos',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/?order=sale',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/?order=sale',
#      'children': [],
#      'article_count': 17058},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/?order=sale',
#      'children': [],
#      'article_count': 6274},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/?order=sale',
#      'children': [],
#      'article_count': 3674},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/?order=sale',
#      'children': [],
#      'article_count': 1688},
#     {'label': 'Luxe',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/?order=sale',
#      'children': [],
#      'article_count': 2992}],
#    'article_count': 26146}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/?order=sale'},
#     {'label': 'Promos',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/?order=sale'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Promos',
#       'seo_label': 'Promotions enfant',
#       'reset_url': '/?order=sale',
#       'id': '9574'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/?order=sale',
#   'reset_url': '/promo-enfant/?order=sale',
#   'app_url': '?urlKey=promo-enfant&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Promos',
#     'seo_label': 'Promotions enfant',
#     'reset_url': '/?order=sale',
#     'id': '9574'}]},
#  'selectedFilters': {'categories': ['promo-enfant']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': None,
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/2aa1504a-c499-4a15-a2ce-544fa67e0dee/d8759a0f-7e87-4fde-b46d-412315870382/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=1dc1c800-435f-4f5f-b5c2-4b0ba70b8aa3&timeUnit=null&timeUnitCount=null&uuid=746e3c2d-5977-40a7-aabe-7f92394f0510&bid=null&requestId=99f80fe9-2d89-475d-a356-9e6b669d418b&s=776C523A5C680478C34217D650321A11'],
#    'images': [{'aspect_ratio': None,
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/3200/549/3500/spp-media-p1/97f5aca2acca45909e295273504f8fa6/a61ff6668ec149f8be6a9a4dc4f92b9d.jpeg',
#      'image_width': None},
#     {'aspect_ratio': None,
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/480/555/960/819/750/spp-media-p1/7c23cf18c10849218dd88c63ae1bb362/ad5b3193843c4b49ae2453204896be67.jpeg',
#      'image_width': None}],
#    'creative_id': '1dc1c800-435f-4f5f-b5c2-4b0ba70b8aa3',
#    'campaign_id': '2aa1504a-c499-4a15-a2ce-544fa67e0dee',
#    'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#    'campaign_source_id': 'RQsmB4tXTAC',
#    'text_fields': {'cta': "J'en profite",
#     'bg_color': '#940000',
#     'legal_claim': "*Offre valable jusqu'au 17/12/2019 à 23h59 sur les articles soldés et les prix minis, à partir de 90€ d'achat.",
#     'voucher_code': 'STAYFRESH',
#     'title': "JUSQU'À -50% ET -20% EXTRA",
#     'type': 'sales',
#     'sales_template': 'Voucher',
#     'byline': 'Juste à temps pour Noël ⏰',
#     'voucher_label': 'Code promo*'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#       'brand_code': '-1',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': '2Ch-9b50T70V+pqk',
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'RQsmB4tXTAC',
#       'request_id': '99f80fe9-2d89-475d-a356-9e6b669d418b',
#       'campaign_id': '2aa1504a-c499-4a15-a2ce-544fa67e0dee',
#       'creative_id': '1dc1c800-435f-4f5f-b5c2-4b0ba70b8aa3'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'brand_code': '-1',
#        'adId': 'oCWj-YgNSJa',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '2Ch-9b50T70V+pqk',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': '99f80fe9-2d89-475d-a356-9e6b669d418b',
#        'campaign_id': '2aa1504a-c499-4a15-a2ce-544fa67e0dee',
#        'creative_id': '1dc1c800-435f-4f5f-b5c2-4b0ba70b8aa3'},
#       'dimension74': {'adId': 'oCWj-YgNSJa'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'brand_code': '-1',
#        'adId': 'oCWj-YgNSJa',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '2Ch-9b50T70V+pqk',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': '99f80fe9-2d89-475d-a356-9e6b669d418b',
#        'campaign_id': '2aa1504a-c499-4a15-a2ce-544fa67e0dee',
#        'creative_id': '1dc1c800-435f-4f5f-b5c2-4b0ba70b8aa3'},
#       'dimension74': {'adId': 'oCWj-YgNSJa'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/2aa1504a-c499-4a15-a2ce-544fa67e0dee/d8759a0f-7e87-4fde-b46d-412315870382/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=1dc1c800-435f-4f5f-b5c2-4b0ba70b8aa3&timeUnit=null&timeUnitCount=null&uuid=07408ff9-e9c0-4e02-a03a-7b05f832bbdb&bid=null&requestId=99f80fe9-2d89-475d-a356-9e6b669d418b&s=798A0EC359FA0E4C0B3E1B71AB3C135A'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': '2Ch-9b50T70V+pqk',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'campaign_id': '2aa1504a-c499-4a15-a2ce-544fa67e0dee',
#      'creative_id': '1dc1c800-435f-4f5f-b5c2-4b0ba70b8aa3',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'brand_code': '-1',
#      'adId': 'oCWj-YgNSJa',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': '2Ch-9b50T70V+pqk',
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'request_id': '99f80fe9-2d89-475d-a356-9e6b669d418b',
#      'campaign_id': '2aa1504a-c499-4a15-a2ce-544fa67e0dee',
#      'creative_id': '1dc1c800-435f-4f5f-b5c2-4b0ba70b8aa3'}},
#    'click_url': 'https://www.zalando.fr/promo-enfant/?camp=fr_aw19_fresh_days_2019_49&sale=true'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/c4b286d1-fd4b-4158-a08b-3b82a0041207/d8759a0f-7e87-4fde-b46d-412315870382/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=9f72cbcd-e544-4f3b-b2d2-641c2260a753&timeUnit=DAY&timeUnitCount=1&uuid=2c16bacb-5e33-48ed-97ef-8f84a0794535&bid=null&requestId=e0d08ea2-2106-4553-9126-cdc186eca850&s=DCE7859444B8A3DDF398034702479C70'],
#    'images': [{'aspect_ratio': '9:13',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/a4a0109a-bfcd-418a-9e0c-f81eed67bf9c.jpg',
#      'image_width': 792}],
#    'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753',
#    'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#    'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#    'text_fields': {'cta': 'Jusqu’à -50%',
#     'title': 'Sneakers',
#     'sales_template': 'None'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'catalog',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#       'brand_code': '-1',
#       'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#       'flow_id': '2Ch-9b50T70V+pqk',
#       'time_unit': 'DAY',
#       'time_unit_count': 1,
#       'shop_slot_id': 'in_catalog',
#       'campaign_source_id': 'undefined',
#       'request_id': 'e0d08ea2-2106-4553-9126-cdc186eca850',
#       'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#       'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753'}},
#     'view': {'type': 'teaser view',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753',
#      'name': 'Sneakers',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#        'brand_code': '-1',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': '2Ch-9b50T70V+pqk',
#        'time_unit': 'DAY',
#        'time_unit_count': 1,
#        'shop_slot_id': 'in_catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': 'e0d08ea2-2106-4553-9126-cdc186eca850',
#        'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#        'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753'}}},
#     'click': {'type': 'teaser click',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753',
#      'name': 'Sneakers',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#        'brand_code': '-1',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': '2Ch-9b50T70V+pqk',
#        'time_unit': 'DAY',
#        'time_unit_count': 1,
#        'shop_slot_id': 'in_catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': 'e0d08ea2-2106-4553-9126-cdc186eca850',
#        'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#        'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/c4b286d1-fd4b-4158-a08b-3b82a0041207/d8759a0f-7e87-4fde-b46d-412315870382/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=9f72cbcd-e544-4f3b-b2d2-641c2260a753&timeUnit=DAY&timeUnitCount=1&uuid=e1a86f08-5f64-4d31-a774-9d2dcf0a6937&bid=null&requestId=e0d08ea2-2106-4553-9126-cdc186eca850&s=B4C7B2EE3DB0D18131FD9B58604BC2FE'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': '2Ch-9b50T70V+pqk',
#      'entity_id': None,
#      'shop_slot_id': 'in_catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#      'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753',
#      'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#      'brand_code': '-1',
#      'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#      'flow_id': '2Ch-9b50T70V+pqk',
#      'time_unit': 'DAY',
#      'time_unit_count': 1,
#      'shop_slot_id': 'in_catalog',
#      'campaign_source_id': 'undefined',
#      'request_id': 'e0d08ea2-2106-4553-9126-cdc186eca850',
#      'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#      'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753'}},
#    'click_url': 'https://www.zalando.fr/collections/Sqklq-J7RqK/?order=sale'},
#   'channel_name': 'CF',
#   'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951'},
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)

# %%
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   NI116D04M-Q11  COURT BOROUGH MID WINTERIZED  - Chaussures pre...
# 1   GP024K05M-C11  BOYS ACTIVE ARCH  - Sweat à capuche - light he...
# 2   NI114D03N-M11  MD RUNNER 2 - Baskets basses - sequoia/olive c...
# 3   CO414D07T-B11  CHUCK TAYLOR ALL STAR ON MARS - Baskets montan...
# 4   NI113D08C-Q11             RENEW LUCENT - Mocassins - black/white
# ..            ...                                                ...
# 79  M8523K02H-A11                   MARLEE - Sweatshirt - white/blue
# 80  P0213I00Z-K11          BOUBA HALLEY - Bottines - blue/multicolor
# 81  NI124G00J-K11              TEE BABY - T-shirt imprimé - obsidian
# 82  LA224G041-A11  SHORT SLEEVED COLLAR - Polo - flour/navy blue-...
# 83  NI114D0CC-Q11          AIR FORCE 1 - Baskets basses - black/gold
#
#                                            sizes  \
# 0     [17, 18.5, 19.5, 21, 22, 23.5, 25, 26, 27]
# 1             [4-5a, 6-7a, 8-9a, 10-11a, 12-13a]
# 2   [28, 28.5, 29.5, 30, 31.5, 32, 33.5, 34, 35]
# 3                   [18, 19, 20, 21, 22, 23, 24]
# 4         [17, 18.5, 19.5, 21, 22, 23.5, 25, 26]
# ..                                           ...
# 79            [2a, 3a, 4a, 6a, 7a, 8a, 10a, 12a]
# 80                          [21, 22, 23, 24, 26]
# 81                               [12a, 18a, 24a]
# 82               [4a, 5a, 6a, 8a, 10a, 12a, 14a]
# 83      [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40]
#
#                                               url_key  \
# 0   nike-sportswear-court-borough-mid-winterized-b...
# 1       gap-boys-active-arch-sweatshirt-gp024k05m-c11
# 2   nike-sportswear-md-runner-2-baskets-basses-ni1...
# 3   converse-chuck-taylor-all-star-on-mars-baskets...
# 4   nike-sportswear-renew-lucent-baskets-basses-bl...
# ..                                                ...
# 79     molo-marlee-sweatshirt-whiteblue-m8523k02h-a11
# 80     shoo-pom-bottines-bluemulticolor-p0213i00z-k11
# 81  nike-sportswear-tee-baby-t-shirt-imprime-obsid...
# 82  lacoste-short-sleeved-collar-polo-flournavy-bl...
# 83  nike-sportswear-air-force-1-baskets-basses-bla...
#
#                                                 media       brand_name  \
# 0   [{'path': 'NI/11/6D/04/MQ/11/NI116D04M-Q11@8.j...  Nike Sportswear
# 1   [{'path': 'GP/02/4K/05/MC/11/GP024K05M-C11@8.j...              GAP
# 2   [{'path': 'NI/11/4D/03/NM/11/NI114D03N-M11@18....  Nike Sportswear
# 3   [{'path': 'CO/41/4D/07/TB/11/CO414D07T-B11@10....         Converse
# 4   [{'path': 'NI/11/3D/08/CQ/11/NI113D08C-Q11@8.j...  Nike Sportswear
# ..                                                ...              ...
# 79  [{'path': 'M8/52/3K/02/HA/11/M8523K02H-A11@4.j...             Molo
# 80  [{'path': 'P0/21/3I/00/ZK/11/P0213I00Z-K11@3.j...         Shoo Pom
# 81  [{'path': 'NI/12/4G/00/JK/11/NI124G00J-K11@12....  Nike Sportswear
# 82  [{'path': 'LA/22/4G/04/1A/11/LA224G041-A11@7.j...          Lacoste
# 83  [{'path': 'NI/11/4D/0C/CQ/11/NI114D0CC-Q11@8.j...  Nike Sportswear
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79        True              []
# 80       False              []
# 81       False              []
# 82        True              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 1   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 2   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 3   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 4   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 80  [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 81  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 82  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 83  [{'key': 'campaign', 'value': 'HOT DROP', 'tra...          shoe
#
#                                     delivery_promises price.original  \
# 0                                                  []        49,95 €
# 1   [{'key': 'fast_delivery_flag', 'label': 'Livré...        29,95 €
# 2                                                  []        37,95 €
# 3   [{'key': 'fast_delivery_flag', 'label': 'Livré...        54,95 €
# 4                                                  []        44,95 €
# ..                                                ...            ...
# 79                                                 []        54,95 €
# 80                                                 []        79,95 €
# 81                                                 []        14,95 €
# 82                                                 []        84,95 €
# 83                                                 []        84,95 €
#
#    price.promotional  price.has_different_prices  \
# 0            34,95 €                       False
# 1            20,95 €                       False
# 2            28,45 €                       False
# 3            32,95 €                       False
# 4            26,95 €                        True
# ..               ...                         ...
# 79           27,45 €                       False
# 80           39,95 €                       False
# 81            8,95 €                       False
# 82           46,45 €                        True
# 83           67,95 €                       False
#
#     price.has_different_original_prices  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 79                                False
# 80                                False
# 81                                False
# 82                                False
# 83                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                    True
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
# [84 rows x 17 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
# /home/almsasantos/miniconda3/envs/data_env/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#               amount          brand_name delivery_promises family_articles  \
# sku
# LA224G047-K11    NaN             Lacoste                []              []
# TO124G05S-Q11    NaN      Tommy Hilfiger                []              []
# NI113D08E-Q11    NaN     Nike Sportswear                []              []
# NI124D00T-Q11    NaN     Nike Sportswear                []              []
# LE223G042-A11    NaN             Levi's®                []              []
# ...              ...                 ...               ...             ...
# KE543A08W-L12    NaN                Keen                []              []
# N1243A0R4-C12    NaN    Nike Performance                []              []
# CO414D078-I11    NaN            Converse                []              []
# AD543A200-Q11    NaN  adidas Performance                []              []
# L0643D00P-K11    NaN       Lacoste Sport                []              []
#
#                                                            flags  is_premium  \
# sku
# LA224G047-K11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...        True
# TO124G05S-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...        True
# NI113D08E-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# NI124D00T-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# LE223G042-A11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# ...                                                          ...         ...
# KE543A08W-L12  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...       False
# N1243A0R4-C12  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...       False
# CO414D078-I11  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...       False
# AD543A200-Q11  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...       False
# L0643D00P-K11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
#
#                                                            media  \
# sku
# LA224G047-K11  [{'path': 'LA/22/4G/04/7K/11/LA224G047-K11@6.j...
# TO124G05S-Q11  [{'path': 'TO/12/4G/05/SQ/11/TO124G05S-Q11@6.j...
# NI113D08E-Q11  [{'path': 'NI/11/3D/08/EQ/11/NI113D08E-Q11@5.j...
# NI124D00T-Q11  [{'path': 'NI/12/4D/00/TQ/11/NI124D00T-Q11@2.j...
# LE223G042-A11  [{'path': 'LE/22/3G/04/2A/11/LE223G042-A11@7.j...
# ...                                                          ...
# KE543A08W-L12  [{'path': 'KE/54/3A/08/WL/12/KE543A08W-L12@3.j...
# N1243A0R4-C12  [{'path': 'N1/24/3A/0R/4C/12/N1243A0R4-C12@3.j...
# CO414D078-I11  [{'path': 'CO/41/4D/07/8I/11/CO414D078-I11@8.j...
# AD543A200-Q11  [{'path': 'AD/54/3A/20/0Q/11/AD543A200-Q11@3.j...
# L0643D00P-K11  [{'path': 'L0/64/3D/00/PK/11/L0643D00P-K11@9.j...
#
#                                                             name  \
# sku
# LA224G047-K11              BOY TEE - T-shirt imprimé - navy blue
# TO124G05S-Q11          BOYS BASIC  - T-shirt basique - meteorite
# NI113D08E-Q11  AIR MAX 270 REACT - Mocassins - black/white/hy...
# NI124D00T-Q11   CHEVRON COVERALL BABY - Combinaison - anthracite
# LE223G042-A11        CURTSY MINNIE TEE - T-shirt imprimé - white
# ...                                                          ...
# KE543A08W-L12  CHANDLER CNX - Chaussures de marche - tahitian...
# N1243A0R4-C12  MERCURIAL VAPOR 12 CLUB MG - Chaussures de foo...
# CO414D078-I11  CHUCK TAYLOR ALL STAR - Baskets montantes - wa...
# AD543A200-Q11  COPA 19.3 FG - Chaussures de foot à crampons -...
# L0643D00P-K11  TENNIS DJOKOVIC - T-shirt de sport - navy blue...
#
#               price.base_price  price.has_different_original_prices  \
# sku
# LA224G047-K11              NaN                                False
# TO124G05S-Q11              NaN                                False
# NI113D08E-Q11              NaN                                False
# NI124D00T-Q11              NaN                                False
# LE223G042-A11              NaN                                False
# ...                        ...                                  ...
# KE543A08W-L12              NaN                                 True
# N1243A0R4-C12              NaN                                 True
# CO414D078-I11              NaN                                 True
# AD543A200-Q11              NaN                                 True
# L0643D00P-K11              NaN                                 True
#
#                price.has_different_prices  \
# sku
# LA224G047-K11                        True
# TO124G05S-Q11                        True
# NI113D08E-Q11                        True
# NI124D00T-Q11                        True
# LE223G042-A11                       False
# ...                                   ...
# KE543A08W-L12                        True
# N1243A0R4-C12                        True
# CO414D078-I11                        True
# AD543A200-Q11                        True
# L0643D00P-K11                        True
#
#                price.has_different_promotional_prices  \
# sku
# LA224G047-K11                                    True
# TO124G05S-Q11                                    True
# NI113D08E-Q11                                    True
# NI124D00T-Q11                                    True
# LE223G042-A11                                   False
# ...                                               ...
# KE543A08W-L12                                   False
# N1243A0R4-C12                                   False
# CO414D078-I11                                   False
# AD543A200-Q11                                   False
# L0643D00P-K11                                   False
#
#                price.has_discount_on_selected_sizes_only price.original  \
# sku
# LA224G047-K11                                      False        38,95 €
# TO124G05S-Q11                                      False        14,95 €
# NI113D08E-Q11                                      False        94,95 €
# NI124D00T-Q11                                      False        31,95 €
# LE223G042-A11                                      False        23,95 €
# ...                                                  ...            ...
# KE543A08W-L12                                      False        47,95 €
# N1243A0R4-C12                                      False        31,95 €
# CO414D078-I11                                      False        39,95 €
# AD543A200-Q11                                      False        31,95 €
# L0643D00P-K11                                      False        70,00 €
#
#               price.promotional product_group  \
# sku
# LA224G047-K11           19,45 €      clothing
# TO124G05S-Q11           11,20 €      clothing
# NI113D08E-Q11           56,95 €          shoe
# NI124D00T-Q11           15,95 €      clothing
# LE223G042-A11           11,95 €      clothing
# ...                         ...           ...
# KE543A08W-L12           47,95 €          shoe
# N1243A0R4-C12           31,95 €          shoe
# CO414D078-I11           39,95 €          shoe
# AD543A200-Q11           31,95 €          shoe
# L0643D00P-K11           70,00 €      clothing
#
#                                                       sizes  \
# sku
# LA224G047-K11  [2a, 3y, 4a, 5a, 6a, 8a, 10a, 12a, 14a, 16a]
# TO124G05S-Q11      [4a, 5a, 6a, 7a, 8a, 10a, 12a, 14a, 16a]
# NI113D08E-Q11                    [28.5, 29.5, 30, 31.5, 34]
# NI124D00T-Q11                                [0-3a, 3a, 6a]
# LE223G042-A11                      [2a, 3a, 4a, 5a, 6a, 7a]
# ...                                                     ...
# KE543A08W-L12                                  [37, 38, 39]
# N1243A0R4-C12                                    [38, 38.5]
# CO414D078-I11                                      [32, 35]
# AD543A200-Q11                                  [38, 37 1/3]
# L0643D00P-K11                                     [8a, 12a]
#
#                                                          url_key
# sku
# LA224G047-K11      lacoste-boy-tee-t-shirt-imprime-la224g047-k11
# TO124G05S-Q11  tommy-hilfiger-boys-basic-t-shirt-basique-to12...
# NI113D08E-Q11  nike-sportswear-air-max-270-react-baskets-bass...
# NI124D00T-Q11  nike-sportswear-chevron-coverall-baby-combinai...
# LE223G042-A11  levisr-curtsy-minnie-tee-t-shirt-imprime-white...
# ...                                                          ...
# KE543A08W-L12  keen-chandler-cnx-chaussures-de-randonnee-ke54...
# N1243A0R4-C12  nike-performance-vapor-12-club-mg-chaussures-d...
# CO414D078-I11  converse-chuck-taylor-all-star-baskets-montant...
# AD543A200-Q11  adidas-performance-copa-193-fg-chaussures-de-f...
# L0643D00P-K11  lacoste-sport-tennis-djokovic-polo-navy-blueto...
#
# [26142 rows x 18 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'OVS'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Nike Sportswear'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
