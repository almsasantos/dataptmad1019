# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0"}

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %%
response = requests.get(url, headers=headers)
results = response.json()
results
# Out:
# {'total_count': 112202,
#  'pagination': {'page_count': 892, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'VA215B000-Q12',
#    'name': 'OLD SKOOL - Chaussures de skate - black',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '67,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '47',
#     '48',
#     '49',
#     '50'],
#    'url_key': 'vans-old-skool-baskets-basses-va215b000-q12',
#    'media': [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'GS2rkdweTwu',
#      'url_key': '/outfits/GS2rkdweTwu',
#      'media': [{'path': 'cfb4ee75b7c14cf99c9a8d51e43fc423/d5bd6dac27bf4c41b7aa90648eff13ab.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'LUD31E003-S11'},
#       {'id': 'DP621G00X-N11'},
#       {'id': '2SW51L0B3-F11'},
#       {'id': 'Z1721A043-Q11'},
#       {'id': 'VA215B000-Q12'}]}],
#    'delivery_promises': []},
#   {'sku': 'NL011N0AH-Q11',
#    'name': 'BRISK - Bottines - black',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '22,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '41', '42'],
#    'url_key': 'new-look-brisk-bottines-black-nl011n0ah-q11',
#    'media': [{'path': 'NL/01/1N/0A/HQ/11/NL011N0AH-Q11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Look',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD121D0HV-Q11',
#    'name': 'ADICOLOR TREFOIL GRAPHIC TEE - T-shirt imprimé - black',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '22,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-t-shirt-imprime-black-ad121d0hv-q11',
#    'media': [{'path': 'AD/12/1D/0H/VQ/11/AD121D0HV-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1D/0H/VQ/11/AD121D0HV-Q11@14.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TW421IA0N-Q11',
#    'name': 'Gilet - black/white',
#    'price': {'original': '38,99\xa0€',
#     'promotional': '31,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'twintip-gilet-black-white-tw421ia0n-q11',
#    'media': [{'path': 'TW/42/1I/A0/NQ/11/TW421IA0N-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TW/42/1I/A0/NQ/11/TW421IA0N-Q11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'TWINTIP',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD121J0IH-G11',
#    'name': 'LOCK UP - Veste légère - scarlet',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '29,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34', '36', '38', '40', '42', '44', '46', '48'],
#    'url_key': 'adidas-originals-lock-up-veste-de-survetement-ad121j0ih-g11',
#    'media': [{'path': 'AD/12/1J/0I/HG/11/AD121J0IH-G11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1J/0I/HG/11/AD121J0IH-G11@15.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'UG111Y00A-Q11',
#    'name': 'CLASSIC MINI II - Bottines - black',
#    'price': {'original': '169,95\xa0€',
#     'promotional': '152,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42', '43'],
#    'url_key': 'ugg-classic-mini-ii-bottines-ug111y00a-q11',
#    'media': [{'path': 'UG/11/1Y/00/AQ/11/UG111Y00A-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'UGG',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD121A0AE-Q11',
#    'name': 'ADICOLOR TREFOIL TIGHT - Legging - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '22,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-trefoil-tight-legging-ad121a0ae-q11',
#    'media': [{'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'EV421N02Y-Q11',
#    'name': 'Jeans Skinny - black',
#    'price': {'original': '31,99\xa0€',
#     'promotional': '19,19\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '44', '46'],
#    'url_key': 'evenandodd-jeans-skinny-black-ev421n02y-q11',
#    'media': [{'path': 'EV/42/1N/02/YQ/11/EV421N02Y-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1N/02/YQ/11/EV421N02Y-Q11@4.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'EV421N03J-K12',
#    'name': 'Jean boyfriend - blue',
#    'price': {'original': '34,99\xa0€',
#     'promotional': '27,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44', '46'],
#    'url_key': 'evenandodd-jean-boyfriend-blue-ev421n03j-k12',
#    'media': [{'path': 'EV/42/1N/03/JK/12/EV421N03J-K12@16.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1N/03/JK/12/EV421N03J-K12@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'V1021D0PW-Q11',
#    'name': 'T-shirt à manches longues - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44'],
#    'url_key': 'vila-vimary-t-shirt-a-manches-longues-black-v1021d0pw-q11',
#    'media': [{'path': 'V1/02/1D/0P/WQ/11/V1021D0PW-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'V1/02/1D/0P/WQ/11/V1021D0PW-Q11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D0CK-Q11',
#    'name': 'Baskets basses - black',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '39', '40'],
#    'url_key': 'nike-sportswear-court-borough-baskets-basses-ni114d0ck-q11',
#    'media': [{'path': 'NI/11/4D/0C/KQ/11/NI114D0CK-Q11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD121A099-K13',
#    'name': 'Pantalon de survêtement - dark steel',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '42,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-pantalon-de-survetement-dark-steel-ad121a099-k13',
#    'media': [{'path': 'AD/12/1A/09/9K/13/AD121A099-K13@15.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/09/9K/13/AD121A099-K13@17.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI121D0EG-Q11',
#    'name': 'TEE ICON - T-shirt à manches longues - black/white',
#    'price': {'original': '28,95\xa0€',
#     'promotional': '23,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-tee-icon-t-shirt-a-manches-longues-blackwhite-ni121d0eg-q11',
#    'media': [{'path': 'NI/12/1D/0E/GQ/11/NI121D0EG-Q11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1D/0E/GQ/11/NI121D0EG-Q11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'M0Q21N061-Q11',
#    'name': 'VICE COATED FRONT - Jeans Skinny - black',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '33,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42'],
#    'url_key': 'missguided-vice-coated-front-jeans-skinny-black-m0q21n061-q11',
#    'media': [{'path': 'M0/Q2/1N/06/1Q/11/M0Q21N061-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'M0/Q2/1N/06/1Q/11/M0Q21N061-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Missguided',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI121A07O-Q11',
#    'name': 'CLUB  - Legging - black/white',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-club-legging-ni121a07o-q11',
#    'media': [{'path': 'NI/12/1A/07/OQ/11/NI121A07O-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1A/07/OQ/11/NI121A07O-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ST311M00V-Q11',
#    'name': 'ISAAC - Cuissardes - black',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '87,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'steve-madden-bottes-black-st311m00v-q11',
#    'media': [{'path': 'ST/31/1M/00/VQ/11/ST311M00V-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Steve Madden',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'tGTyWbSES0S',
#      'url_key': '/outfits/tGTyWbSES0S',
#      'media': [{'path': 'eafe0adcfa2040979e42c180df1360fb/277d8ce8562e448caeb512dabacb4bb0.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'f6dfabdd-0bc8-407a-b326-cae282c9d90b',
#       'name': 'hoardoftrends',
#       'media': [{'path': '4e89f67719da4bb2b718db7578698646/e1761ab18f094c7aac40feefeff5b34a.jpeg',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'UNK21G00D-I11'},
#       {'id': 'MOQ21D02X-M11'},
#       {'id': 'TP751H0L4-M11'},
#       {'id': 'MOQ21B01C-Q11'},
#       {'id': 'ST311M00V-Q11'}]}],
#    'delivery_promises': []},
#   {'sku': 'VE121U088-M11',
#    'name': 'VMAGNES BREEZE - Parka - peat',
#    'price': {'original': '48,99\xa0€',
#     'promotional': '44,09\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'XL'],
#    'url_key': 'vero-moda-vmagnes-breeze-parka-peat-ve121u088-m11',
#    'media': [{'path': 'VE/12/1U/08/8M/11/VE121U088-M11@17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1U/08/8M/11/VE121U088-M11@20.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'V1021B0EZ-J11',
#    'name': 'VITYSHA SKIRT - Jupe plissée - rose smoke',
#    'price': {'original': '48,99\xa0€',
#     'promotional': '26,89\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44', '46'],
#    'url_key': 'vila-vitysha-skirt-jupe-plissee-rose-smoke-v1021b0ez-j11',
#    'media': [{'path': 'V1/02/1B/0E/ZJ/11/V1021B0EZ-J11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'V1/02/1B/0E/ZJ/11/V1021B0EZ-J11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PU111A0C7-A12',
#    'name': 'NOVA - Baskets basses - white/milky blue',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '37.5', '38.5', '39', '40', '40.5', '41'],
#    'url_key': 'puma-nova-baskets-basses-pu111a0c7-a12',
#    'media': [{'path': 'PU/11/1A/0C/7A/12/PU111A0C7-A12@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD111A0XH-J11',
#    'name': 'FALCON  - Baskets basses - glow pink/grey two/footwear white',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '49,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3'],
#    'url_key': 'adidas-originals-baskets-basses-glow-pinkgrey-twofootwear-white-ad111a0xh-j11',
#    'media': [{'path': 'AD/11/1A/0X/HJ/11/AD111A0XH-J11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'H0421D050-K11',
#    'name': 'CORE PRINTED LOGO TEE - T-shirt imprimé - navy',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '12,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'L'],
#    'url_key': 'hollister-co-core-printed-logo-tee-t-shirt-imprime-h0421d050-k11',
#    'media': [{'path': 'H0/42/1D/05/0K/11/H0421D050-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'H0/42/1D/05/0K/11/H0421D050-K11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Hollister Co.',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TOB21U01L-K11',
#    'name': 'ESSENTIAL HOODED JACKET - Doudoune - black iris',
#    'price': {'original': '219,95\xa0€',
#     'promotional': '186,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'tommy-jeans-essential-hooded-jacket-doudoune-black-iris-tob21u01l-k11',
#    'media': [{'path': 'TO/B2/1U/01/LK/11/TOB21U01L-K11@20.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/B2/1U/01/LK/11/TOB21U01L-K11@23.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Jeans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD111A0Q7-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/gold metallic',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitegold-metallic-ad111a0q7-a11',
#    'media': [{'path': 'AD/11/1A/0Q/7A/11/AD111A0Q7-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NL011A0PX-Q11',
#    'name': 'ANGELINA - Bottes - black',
#    'price': {'original': '47,99\xa0€',
#     'promotional': '38,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40'],
#    'url_key': 'new-look-angelina-bottes-black-nl011a0px-q11',
#    'media': [{'path': 'NL/01/1A/0P/XQ/11/NL011A0PX-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Look',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'DP511N08V-Q11',
#    'name': 'ASTRID HEEL ZIP - Boots à talons - black',
#    'price': {'original': '49,99\xa0€',
#     'promotional': '39,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40', '41', '42'],
#    'url_key': 'dorothy-perkins-astrid-heel-zip-boots-a-talons-black-dp511n08v-q11',
#    'media': [{'path': 'DP/51/1N/08/VQ/11/DP511N08V-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Dorothy Perkins',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NE211A0BW-A11',
#    'name': 'WX608 - Baskets basses - white/purple',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '41.5'],
#    'url_key': 'new-balance-wx608-baskets-basses-whitepurple-ne211a0bw-a11',
#    'media': [{'path': 'NE/21/1A/0B/WA/11/NE211A0BW-A11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Balance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'M9121U0ML-K11',
#    'name': 'BRIE - Veste polaire - blue',
#    'price': {'original': '59,99\xa0€',
#     'promotional': '39,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L'],
#    'url_key': 'mango-brie-veste-dhiver-m9121u0ml-k11',
#    'media': [{'path': 'M9/12/1U/0M/LK/11/M9121U0ML-K11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'M9/12/1U/0M/LK/11/M9121U0ML-K11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Mango',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-33%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE221J00U-C11',
#    'name': 'GRAPHIC SPORT - Sweat à capuche - smokestack heather',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '48,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'levisr-graphic-sport-sweatshirt-smokestack-heather-le221j00u-c11',
#    'media': [{'path': 'LE/22/1J/00/UC/11/LE221J00U-C11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1J/00/UC/11/LE221J00U-C11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VE121C1AK-K11',
#    'name': 'Robe en jean - light blue denim',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '31,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'vero-moda-robe-en-jean-light-blue-denim-ve121c1ak-k11',
#    'media': [{'path': 'VE/12/1C/1A/KK/11/VE121C1AK-K11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1C/1A/KK/11/VE121C1AK-K11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'K4851D00B-Q11',
#    'name': 'BUCKLE BELT - Ceinture - black',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '80,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L'],
#    'url_key': 'karl-lagerfeld-buckle-belt-ceinture-black-k4851d00b-q11',
#    'media': [{'path': 'K4/85/1D/00/BQ/11/K4851D00B-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'K4/85/1D/00/BQ/11/K4851D00B-Q11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'KARL LAGERFELD',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'TO121D0DN-K11',
#    'name': 'HERITAGE CREW NECK GRAPHIC TEE - T-shirt imprimé - midnight',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'tommy-hilfiger-heritage-crew-neck-graphic-tee-t-shirt-imprime-to121d0dn-k11',
#    'media': [{'path': 'TO/12/1D/0D/NK/11/TO121D0DN-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/12/1D/0D/NK/11/TO121D0DN-K11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'FID21D00R-Q11',
#    'name': 'SHINAKO TEE - T-shirt imprimé - black/bright white',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '31,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42'],
#    'url_key': 'fila-petite-shinako-tee-t-shirt-imprime-blackbright-white-fid21d00r-q11',
#    'media': [{'path': 'FI/D2/1D/00/RQ/11/FID21D00R-Q11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'FI/D2/1D/00/RQ/11/FID21D00R-Q11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fila Petite',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'assortmentArea', 'value': 'Petite', 'tracking_value': 'petite'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'M3221U00D-Q12',
#    'name': 'Manteau classique - sky captain',
#    'price': {'original': '139,99\xa0€',
#     'promotional': '76,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44'],
#    'url_key': 'mintandberry-manteau-classique-sky-captain-m3221u00d-q12',
#    'media': [{'path': 'M3/22/1U/00/DQ/12/M3221U00D-Q12@17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'M3/22/1U/00/DQ/12/M3221U00D-Q12@16.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'mint&berry',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI111A0FK-Q12',
#    'name': 'REACT ELEMENT 55 PRM - Baskets basses - black/volt/coral stardust/light soft pink/white',
#    'price': {'original': '139,95\xa0€',
#     'promotional': '90,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-react-55-baskets-basses-ni111a0fk-q12',
#    'media': [{'path': 'NI/11/1A/0F/KQ/12/NI111A0FK-Q12@21.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VE121E1PD-G11',
#    'name': 'VMNICKY - Chemisier - port royale/annie',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '22,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'XL'],
#    'url_key': 'vero-moda-vmnicky-chemisier-port-royaleannie-ve121e1pd-g11',
#    'media': [{'path': 'VE/12/1E/1P/DG/11/VE121E1PD-G11@18.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1E/1P/DG/11/VE121E1PD-G11@16.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI112O093-H11',
#    'name': 'SIGNAL D/MS/X - Baskets basses - guava ice/light aqua/hyper crimson/blue hero/cedar/black',
#    'price': {'original': '124,95\xa0€',
#     'promotional': '61,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-signal-dmsx-baskets-basses-ni112o093-h11',
#    'media': [{'path': 'NI/11/2O/09/3H/11/NI112O093-H11@9.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'NI/11/2O/09/3H/11/NI112O093-H11@19.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI111A0D1-A12',
#    'name': 'Baskets basses - sail/white/black',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-zoom-2k-baskets-basses-ni111a0d1-a12',
#    'media': [{'path': 'NI/11/1A/0D/1A/12/NI111A0D1-A12@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'ZA821D037-Q11',
#    'name': '3 PACK - Débardeur - black/white/mottled light grey',
#    'price': {'original': '19,99\xa0€',
#     'promotional': '17,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'L', 'XL', 'XXL'],
#    'url_key': 'zalando-essentials-top-black-white-light-grey-za821d037-q11',
#    'media': [{'path': 'ZA/82/1D/03/7Q/11/ZA821D037-Q11@16.2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ZA/82/1D/03/7Q/11/ZA821D037-Q11@17.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Zalando Essentials',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'DP511A0GQ-Q11',
#    'name': 'TRISTIANNA CLEATED HEELED LONG BOOT - Cuissardes - black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '47,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40'],
#    'url_key': 'dorothy-perkins-tristianna-cleated-heeled-long-boot-cuissardes-black-dp511a0gq-q11',
#    'media': [{'path': 'DP/51/1A/0G/QQ/11/DP511A0GQ-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Dorothy Perkins',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'EV421N053-Q11',
#    'name': 'Jeans Skinny - washed black',
#    'price': {'original': '26,99\xa0€',
#     'promotional': '14,79\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '46'],
#    'url_key': 'evenandodd-jeans-skinny-washed-black-ev421n053-q11',
#    'media': [{'path': 'EV/42/1N/05/3Q/11/EV421N053-Q11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1N/05/3Q/11/EV421N053-Q11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'RE021D01N-K11',
#    'name': 'CROP TEE - T-shirt imprimé - collegiate navy',
#    'price': {'original': '23,95\xa0€',
#     'promotional': '16,75\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'reebok-classic-crop-tee-t-shirt-imprime-collegiate-navy-re021d01n-k11',
#    'media': [{'path': 'RE/02/1D/01/NK/11/RE021D01N-K11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'RE/02/1D/01/NK/11/RE021D01N-K11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Reebok Classic',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VA221D09I-A11',
#    'name': 'TANGLE - T-shirt à manches longues - white',
#    'price': {'original': '37,95\xa0€',
#     'promotional': '30,35\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38', '40', '42', '44'],
#    'url_key': 'vans-tangle-t-shirt-a-manches-longues-white-va221d09i-a11',
#    'media': [{'path': 'VA/22/1D/09/IA/11/VA221D09I-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VA/22/1D/09/IA/11/VA221D09I-A11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD121A0D7-G11',
#    'name': 'TIGHTS - Legging - mystery red/white',
#    'price': {'original': '32,95\xa0€',
#     'promotional': '27,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '46'],
#    'url_key': 'adidas-originals-tights-legging-mystery-redwhite-ad121a0d7-g11',
#    'media': [{'path': 'AD/12/1A/0D/7G/11/AD121A0D7-G11@18.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/0D/7G/11/AD121A0D7-G11@16.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI121A08U-Q11',
#    'name': 'NSW LEGASEE 7/8 FUTURA - Legging - black/white',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '25,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-nsw-legasee-78-futura-legging-blackwhite-ni121a08u-q11',
#    'media': [{'path': 'NI/12/1A/08/UQ/11/NI121A08U-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1A/08/UQ/11/NI121A08U-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'M0Q21C00O-Q11',
#    'name': 'AYVAN OFF SHOULDER - Robe pull - black',
#    'price': {'original': '32,99\xa0€',
#     'promotional': '27,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['M/L', 'S/M'],
#    'url_key': 'missguided-robe-pull-black-m0q21c00o-q11',
#    'media': [{'path': 'M0/Q2/1C/00/OQ/11/M0Q21C00O-Q11@18.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'M0/Q2/1C/00/OQ/11/M0Q21C00O-Q11@15.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Missguided',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI111A0D1-A11',
#    'name': 'Baskets basses - white/black',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '76,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-zoom-2k-baskets-basses-ni111a0d1-a11',
#    'media': [{'path': 'NI/11/1A/0D/1A/11/NI111A0D1-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA211S03A-Q11',
#    'name': 'UA OLD SKOOL PLATFORM - Baskets basses - black/white',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '71,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43'],
#    'url_key': 'vans-baskets-basses-blackwhite-va211s03a-q11',
#    'media': [{'path': 'VA/21/1S/03/AQ/11/VA211S03A-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'a8XchmKJSoa',
#      'url_key': '/outfits/a8XchmKJSoa',
#      'media': [{'path': '2e1307635e394e40b6192429694fe786/6745161ecc15411faa6737cdd956c283.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'SPG31K00E-S11'},
#       {'id': 'EDD21U00C-J11'},
#       {'id': 'QX721D00Z-A11'},
#       {'id': 'QX721N008-K13'},
#       {'id': 'VA211S03A-Q11'},
#       {'id': 'EV451H0M7-Q11'},
#       {'id': '1SN51E00T-D11'}]}],
#    'delivery_promises': []},
#   {'sku': 'NI111A0DD-C12',
#    'name': 'REACT 55 - Baskets basses - football grey/psychic blue/hyper violet',
#    'price': {'original': '129,95\xa0€',
#     'promotional': '77,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-react-element-55-baskets-basses-ni111a0dd-c12',
#    'media': [{'path': 'NI/11/1A/0D/DC/12/NI111A0DD-C12@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'EL921J00Y-Q11',
#    'name': 'TORICES - Sweat à capuche - black',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '46,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38', '40', '42', '44', '46'],
#    'url_key': 'ellesse-torices-sweatshirt-el921j00y-q11',
#    'media': [{'path': 'EL/92/1J/00/YQ/11/EL921J00Y-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EL/92/1J/00/YQ/11/EL921J00Y-Q11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Ellesse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD111A0W3-Q11',
#    'name': 'OZWEEGO  ADIPRENE+ RUNNING-STYLE SHOES - Baskets basses - core black/purple beauty/flash orange',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '77,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
# ...
#     {'key': 'M0Y', 'label': 'Moss Copenhagen', 'is_family': False},
#     {'key': 'MOL', 'label': 'Mossman', 'is_family': False},
#     {'key': 'MOV', 'label': 'Mot-clé', 'is_family': False},
#     {'key': 'MH3', 'label': 'Mother', 'is_family': False},
#     {'key': 'MP4', 'label': 'Mother of Pearl', 'is_family': False},
#     {'key': 'MOD', 'label': 'Moves', 'is_family': False},
#     {'key': 'MRA', 'label': 'MRZ', 'is_family': False},
#     {'key': 'MSA', 'label': 'MS Mode', 'is_family': False},
#     {'key': 'MG6', 'label': 'MSGM', 'is_family': False},
#     {'key': 'MT7', 'label': 'mtng', 'is_family': False},
#     {'key': 'MUF', 'label': 'Mulberry', 'is_family': False},
#     {'key': 'MUE', 'label': 'Musse & Cloud', 'is_family': False},
#     {'key': 'MU3', 'label': 'Mustang', 'is_family': False},
#     {'key': 'TOL',
#      'label': 'MY TRUE ME TOM TAILOR',
#      'family_id': 'TOMT',
#      'is_family': False},
#     {'key': 'MYD', 'label': 'Mykke Hofmann', 'is_family': False},
#     {'key': '1MY', 'label': 'myMo', 'is_family': False},
#     {'key': 'MYG', 'label': 'Mywalit', 'is_family': False},
#     {'key': 'NAA', 'label': 'NA-KD', 'family_id': 'NA02', 'is_family': False},
#     {'key': 'NA5', 'label': 'NAF NAF', 'is_family': False},
#     {'key': 'NAF', 'label': 'Nails Inc', 'is_family': False},
#     {'key': '2NA', 'label': 'Naketano', 'is_family': False},
#     {'key': 'NA6',
#      'label': 'Napapijri',
#      'family_id': 'NA00',
#      'is_family': False},
#     {'key': 'NA1', 'label': 'Native', 'is_family': False},
#     {'key': 'NT5', 'label': 'Needle & Thread', 'is_family': False},
#     {'key': '4NE',
#      'label': 'Neil Barrett',
#      'family_id': 'NE01',
#      'is_family': False},
#     {'key': 'N21', 'label': 'Neom', 'is_family': False},
#     {'key': 'NE1', 'label': 'Neosens', 'is_family': False},
#     {'key': 'ND8', 'label': 'Neuw', 'is_family': False},
#     {'key': 'NE2', 'label': 'New Balance', 'is_family': False},
#     {'key': 'NE3', 'label': 'New Era', 'is_family': False},
#     {'key': 'NE00', 'label': 'New Look', 'is_family': True},
#     {'key': 'NL0',
#      'label': 'New Look',
#      'family_id': 'NE00',
#      'is_family': False},
#     {'key': 'N32',
#      'label': 'New Look Curves',
#      'family_id': 'NE00',
#      'is_family': False},
#     {'key': 'N0B',
#      'label': 'New Look Maternity',
#      'family_id': 'NE00',
#      'is_family': False},
#     {'key': 'NL7',
#      'label': 'New Look Petite',
#      'family_id': 'NE00',
#      'is_family': False},
#     {'key': 'NEB',
#      'label': 'New Look Tall',
#      'family_id': 'NE00',
#      'is_family': False},
#     {'key': 'NED',
#      'label': 'New Look Wide Fit',
#      'family_id': 'NE00',
#      'is_family': False},
#     {'key': '1NE', 'label': 'Newline', 'is_family': False},
#     {'key': 'NX3', 'label': 'Next', 'is_family': False},
#     {'key': 'NG0', 'label': 'NGHTBRD', 'is_family': False},
#     {'key': 'NIKE', 'label': 'Nike', 'is_family': True},
#     {'key': 'NI4',
#      'label': 'Nike Golf',
#      'family_id': 'NIKE',
#      'is_family': False},
#     {'key': 'N12',
#      'label': 'Nike Performance',
#      'family_id': 'NIKE',
#      'is_family': False},
#     {'key': 'NS4',
#      'label': 'Nike SB',
#      'family_id': 'NIKE',
#      'is_family': False},
#     {'key': 'NI1',
#      'label': 'Nike Sportswear',
#      'family_id': 'NIKE',
#      'is_family': False},
#     {'key': 'N16', 'label': 'Nine West', 'is_family': False},
#     {'key': 'NIH', 'label': 'Nioxin', 'is_family': False},
#     {'key': 'NIF', 'label': 'Nip+Fab', 'is_family': False},
#     {'key': 'NI3', 'label': 'Nixon', 'is_family': False},
#     {'key': 'NEG', 'label': 'Nly by Nelly', 'is_family': False},
#     {'key': 'NO8', 'label': 'No Name', 'is_family': False},
#     {'key': 'NN1', 'label': 'Noa Noa', 'is_family': False},
#     {'key': 'N02', 'label': 'Noclaim', 'is_family': False},
#     {'key': 'NO00', 'label': 'Noisy May', 'is_family': True},
#     {'key': 'NM3',
#      'label': 'Noisy May',
#      'family_id': 'NO00',
#      'is_family': False},
#     {'key': 'NM5',
#      'label': 'Noisy May Petite',
#      'family_id': 'NO00',
#      'is_family': False},
#     {'key': 'NOB',
#      'label': 'Noisy May Tall',
#      'family_id': 'NO00',
#      'is_family': False},
#     {'key': 'N14', 'label': 'Noppies', 'is_family': False},
#     {'key': 'NOP', 'label': 'Nordgreen', 'is_family': False},
#     {'key': 'NOE', 'label': 'NORR', 'is_family': False},
#     {'key': 'NB2', 'label': 'Nubikk', 'is_family': False},
#     {'key': 'NU2', 'label': 'Nudie Jeans', 'is_family': False},
#     {'key': 'NUC', 'label': 'Núnoo', 'is_family': False},
#     {'key': 'NU1', 'label': 'Nümph', 'is_family': False},
#     {'key': 'ON5', 'label': "O'Neill", 'is_family': False},
#     {'key': 'OA3', 'label': 'Oakley', 'is_family': False},
#     {'key': 'OA1', 'label': 'Oakwood', 'is_family': False},
#     {'key': 'OA2', 'label': 'Oasis', 'is_family': False},
#     {'key': 'OA5', 'label': 'Oasis Curve', 'is_family': False},
#     {'key': 'OB0', 'label': 'Obey Clothing', 'is_family': False},
#     {'key': 'OB00', 'label': 'Object', 'is_family': True},
#     {'key': 'OB1', 'label': 'Object', 'family_id': 'OB00', 'is_family': False},
#     {'key': 'OB8',
#      'label': 'Object Petite',
#      'family_id': 'OB00',
#      'is_family': False},
#     {'key': 'OB7',
#      'label': 'Object Tall',
#      'family_id': 'OB00',
#      'is_family': False},
#     {'key': 'OD1', 'label': 'ODLO', 'is_family': False},
#     {'key': 'OF00', 'label': 'Office', 'is_family': True},
#     {'key': 'OF2', 'label': 'Office', 'family_id': 'OF00', 'is_family': False},
#     {'key': 'OF4',
#      'label': 'Office Wide Fit',
#      'family_id': 'OF00',
#      'is_family': False},
#     {'key': 'OH0', 'label': 'ohma!', 'is_family': False},
#     {'key': 'OI1', 'label': 'Oilily', 'is_family': False},
#     {'key': 'OLC', 'label': 'Oliver Bonas', 'is_family': False},
#     {'key': 'OB6', 'label': 'Olivia Burton', 'is_family': False},
#     {'key': 'ON9', 'label': 'one more story', 'is_family': False},
#     {'key': 'TE7', 'label': 'One Teaspoon', 'is_family': False},
#     ...],
#    'family_key': 'brand_families'},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4.75,
#     'max': 1610.95,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Soldes',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les Promos'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'OTHER', 'label': 'Autres matières'},
#     {'key': 'CASHMERE', 'label': 'Cachemire'},
#     {'key': 'CAOUTCHOUC', 'label': 'Caoutchouc'},
#     {'key': 'COTTON', 'label': 'Coton'},
#     {'key': 'CROCHETED', 'label': 'Crocheté'},
#     {'key': 'LEATHER', 'label': 'Cuir'},
#     {'key': 'CORD', 'label': 'Côtelé'},
#     {'key': 'DENIM', 'label': 'Denim'},
#     {'key': 'LACE', 'label': 'Dentelle'},
#     {'key': 'FELT', 'label': 'Feutre'},
#     {'key': 'FLANELETTE', 'label': 'Flanelle chaude'},
#     {'key': 'HARDSHELL', 'label': 'Hardshell'},
#     {'key': 'IMITATION_LEATHER', 'label': 'Imitation cuir'},
#     {'key': 'JERSEY', 'label': 'Jersey'},
#     {'key': 'WOOL', 'label': 'Laine'},
#     {'key': 'LINEN', 'label': 'Lin'},
#     {'key': 'MESH', 'label': 'Mesh'},
#     {'key': 'FEATHERS', 'label': 'Plume'},
#     {'key': 'FLEECE', 'label': 'Polaire'},
#     {'key': 'POLYESTER', 'label': 'Polyester'},
#     {'key': 'SATIN', 'label': 'Satin'},
#     {'key': 'SOFTSHELL', 'label': 'Softshell'},
#     {'key': 'SILK', 'label': 'Soie'},
#     {'key': 'RIB', 'label': 'Strié'},
#     {'key': 'SWEAT', 'label': 'Sweat'},
#     {'key': 'SYNTHETIC', 'label': 'Synthétique'},
#     {'key': 'TEXTILE', 'label': 'Textile'},
#     {'key': 'BRAIDED', 'label': 'tressé'},
#     {'key': 'VARNISH', 'label': 'Verni'},
#     {'key': 'VISCOSE', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}],
#    'group_id': 'sustainable'},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'STRIPED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'POLKA_DOT', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'PETITE', 'label': 'Petite'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'vegan',
#    'label': 'Végane',
#    'url_key': 'vegan',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Végane'}],
#    'group_id': 'vegan'}],
#  'total_article_count': 112194,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promos',
#    'id': '8803',
#    'url_key': 'promo-femme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-femme/',
#    'children': [{'label': 'Vêtements',
#      'id': '8838',
#      'url_key': 'promo-mode-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-femme/',
#      'children': [],
#      'article_count': 71987},
#     {'label': 'Chaussures',
#      'id': '8804',
#      'url_key': 'promo-chaussures-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-femme/',
#      'children': [],
#      'article_count': 26787},
#     {'label': 'Sacs et accessoires',
#      'id': '8860',
#      'url_key': 'promo-accessoires-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-femme/',
#      'children': [],
#      'article_count': 12085},
#     {'label': 'Lingerie',
#      'id': '8850',
#      'url_key': 'promo-lingerie-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-lingerie-femme/',
#      'children': [],
#      'article_count': 5847},
#     {'label': 'Luxe',
#      'id': '13429',
#      'url_key': 'promo-luxe-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-femme/',
#      'children': [],
#      'article_count': 8818},
#     {'label': 'Sport',
#      'id': '13286',
#      'url_key': 'promo-sport-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-femme/',
#      'children': [],
#      'article_count': 7609},
#     {'label': 'Beauté',
#      'id': '13478',
#      'url_key': 'beaute-femme-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-femme-promo/',
#      'children': [],
#      'article_count': 1177}],
#    'article_count': 112198}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Femme',
#      'url_key': 'femme',
#      'full_url': '/femme/'},
#     {'label': 'Promos',
#      'url_key': 'promo-femme',
#      'full_url': '/promo-femme/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-femme',
#       'url_key': 'promo-femme',
#       'label': 'Promos',
#       'seo_label': 'Promotions femme',
#       'reset_url': '/',
#       'id': '8803'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-femme/',
#   'reset_url': '/promo-femme/',
#   'app_url': '?urlKey=promo-femme&order=popularity&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-femme',
#     'url_key': 'promo-femme',
#     'label': 'Promos',
#     'seo_label': 'Promotions femme',
#     'reset_url': '/',
#     'id': '8803'}]},
#  'selectedFilters': {'categories': ['promo-femme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': 'Faire du shopping sans culpabiliser ? Avec nos promos pour femme, c’est possible ! Offrez-vous les incontournables de cette saison tels que le bomber XXL ou les loafers à prix réduit. Mais attention, ils partent vite !',
#  'teaser': None,
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)

# %%
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   VA215B000-Q12            OLD SKOOL - Chaussures de skate - black
# 1   NL011N0AH-Q11                           BRISK - Bottines - black
# 2   AD121D0HV-Q11  ADICOLOR TREFOIL GRAPHIC TEE - T-shirt imprimé...
# 3   TW421IA0N-Q11                                Gilet - black/white
# 4   AD121J0IH-G11                   LOCK UP - Veste légère - scarlet
# ..            ...                                                ...
# 79  AD115O0G9-A11  AMERICANA - Baskets basses - footwear white/co...
# 80  EV421N032-K12                              Jean slim - dark blue
# 81  NI111A0IU-Q11                RYZ  - Baskets basses - black/white
# 82  NM321G014-K11       NMDEBRA  - Veste en jean - medium blue denim
# 83  UG111X03U-J11           FLUFF MINI - Bottes de neige - pink dawn
#
#                                                 sizes  \
# 0   [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# 1                            [36, 37, 38, 39, 41, 42]
# 2                    [32, 34, 36, 38, 40, 42, 44, 46]
# 3                                       [XS, S, M, L]
# 4                    [34, 36, 38, 40, 42, 44, 46, 48]
# ..                                                ...
# 79  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# 80                               [36, 38, 40, 44, 46]
# 81  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# 82                               [36, 38, 40, 42, 44]
# 83                               [36, 37, 38, 39, 40]
#
#                                               url_key  \
# 0         vans-old-skool-baskets-basses-va215b000-q12
# 1         new-look-brisk-bottines-black-nl011n0ah-q11
# 2   adidas-originals-t-shirt-imprime-black-ad121d0...
# 3             twintip-gilet-black-white-tw421ia0n-q11
# 4   adidas-originals-lock-up-veste-de-survetement-...
# ..                                                ...
# 79  adidas-originals-americana-baskets-basses-foot...
# 80         evenandodd-jegging-dark-blue-ev421n032-k12
# 81  nike-sportswear-uptear-baskets-basses-ni111a0i...
# 82      noisy-may-nmdebra-veste-en-jean-nm321g014-k11
# 83    ugg-fluff-mini-bottines-pink-dawn-ug111x03u-j11
#
#                                                 media        brand_name  \
# 0   [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12....              Vans
# 1   [{'path': 'NL/01/1N/0A/HQ/11/NL011N0AH-Q11@9.j...          New Look
# 2   [{'path': 'AD/12/1D/0H/VQ/11/AD121D0HV-Q11@13....  adidas Originals
# 3   [{'path': 'TW/42/1I/A0/NQ/11/TW421IA0N-Q11@10....           TWINTIP
# 4   [{'path': 'AD/12/1J/0I/HG/11/AD121J0IH-G11@10....  adidas Originals
# ..                                                ...               ...
# 79  [{'path': 'AD/11/5O/0G/9A/11/AD115O0G9-A11@11....  adidas Originals
# 80  [{'path': 'EV/42/1N/03/2K/12/EV421N032-K12@12....          Even&Odd
# 81  [{'path': 'NI/11/1A/0I/UQ/11/NI111A0IU-Q11@3.j...   Nike Sportswear
# 82  [{'path': 'NM/32/1G/01/4K/11/NM321G014-K11@12....         Noisy May
# 83  [{'path': 'UG/11/1X/03/UJ/11/UG111X03U-J11@9.1...               UGG
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
# 1   [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -10...      clothing
# 3   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': 'Jusqu’à -50...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': 'Jusqu’à -50...          shoe
# 80  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 81  [{'key': 'campaign', 'value': 'HOT DROP', 'tra...          shoe
# 82  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': '-20%', 'tra...          shoe
#
#                                               outfits  \
# 0   [{'id': 'GS2rkdweTwu', 'url_key': '/outfits/GS...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                                     delivery_promises price.original  \
# 0                                                  []        74,95 €
# 1                                                  []        29,99 €
# 2                                                  []        24,95 €
# 3                                                  []        38,99 €
# 4                                                  []        59,95 €
# ..                                                ...            ...
# 79                                                 []        79,95 €
# 80                                                 []        24,99 €
# 81                                                 []        89,95 €
# 82  [{'key': 'fast_delivery_flag', 'label': 'Livré...        29,99 €
# 83                                                 []       199,95 €
#
#    price.promotional  price.has_different_prices  \
# 0            67,45 €                       False
# 1            22,49 €                       False
# 2            22,45 €                        True
# 3            31,15 €                       False
# 4            29,95 €                        True
# ..               ...                         ...
# 79           39,95 €                        True
# 80           19,99 €                       False
# 81           76,45 €                        True
# 82           23,99 €                       False
# 83          159,95 €                       False
#
#     price.has_different_original_prices  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 79                                False
# 80                                False
# 81                                False
# 82                                False
# 83                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                    True
# 80                                   False
# 81                                    True
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount price.base_price
# 0                                       False    NaN              NaN
# 1                                       False    NaN              NaN
# 2                                       False    NaN              NaN
# 3                                       False    NaN              NaN
# 4                                       False    NaN              NaN
# ..                                        ...    ...              ...
# 79                                      False    NaN              NaN
# 80                                      False    NaN              NaN
# 81                                      False    NaN              NaN
# 82                                      False    NaN              NaN
# 83                                      False    NaN              NaN
#
# [84 rows x 20 columns]

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']
total_pages
# Out:
# 892

# %%
df=pd.DataFrame()
for i in range(2, total_pages):
    k=84*i
    url = f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
    response = requests.get(url, headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
# Out:
# /home/almsasantos/miniconda3/envs/data_env/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
df.columns
# Out:
# Index(['amount', 'brand_name', 'delivery_promises', 'family_articles', 'flags',
#        'is_premium', 'media', 'name', 'outfits', 'price.base_price',
#        'price.has_different_original_prices', 'price.has_different_prices',
#        'price.has_different_promotional_prices',
#        'price.has_discount_on_selected_sizes_only', 'price.original',
#        'price.promotional', 'product_group', 'sizes', 'url_key'],
#       dtype='object')

# %%
display(df)
# Out:
#               amount         brand_name delivery_promises family_articles  \
# sku
# JY121I0AI-K11    NaN                JDY                []              []
# UG111X01X-N11    NaN                UGG                []              []
# TO151H0EB-Q11    NaN     Tommy Hilfiger                []              []
# NL021I0E6-Q11    NaN           New Look                []              []
# NI121J0AW-C11    NaN    Nike Sportswear                []              []
# ...              ...                ...               ...             ...
# C7641E034-Q11    NaN           Champion                []              []
# VA111A0M1-Q11    NaN           Vagabond                []              []
# KS821C03T-K11    NaN  Karen by Simonsen                []              []
# AX911N02H-O11    NaN     Call it Spring                []              []
# ON321A10V-C11    NaN               ONLY                []              []
#
#                                                            flags  is_premium  \
# sku
# JY121I0AI-K11  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# UG111X01X-N11  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# TO151H0EB-Q11  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# NL021I0E6-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...       False
# NI121J0AW-C11  [{'key': 'discountRate', 'value': 'Jusqu’à -15...       False
# ...                                                          ...         ...
# C7641E034-Q11  [{'key': 'discountRate', 'value': '-35%', 'tra...       False
# VA111A0M1-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...       False
# KS821C03T-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# AX911N02H-O11  [{'key': 'campaign', 'value': 'Végane', 'track...       False
# ON321A10V-C11  [{'key': 'discountRate', 'value': '-35%', 'tra...       False
#
#                                                            media  \
# sku
# JY121I0AI-K11  [{'path': 'JY/12/1I/0A/IK/11/JY121I0AI-K11@13....
# UG111X01X-N11  [{'path': 'UG/11/1X/01/XN/11/UG111X01X-N11@6.j...
# TO151H0EB-Q11  [{'path': 'TO/15/1H/0E/BQ/11/TO151H0EB-Q11@11....
# NL021I0E6-Q11  [{'path': 'NL/02/1I/0E/6Q/11/NL021I0E6-Q11@4.j...
# NI121J0AW-C11  [{'path': 'NI/12/1J/0A/WC/11/NI121J0AW-C11@4.j...
# ...                                                          ...
# C7641E034-Q11  [{'path': 'C7/64/1E/03/4Q/11/C7641E034-Q11@4.j...
# VA111A0M1-Q11  [{'path': 'VA/11/1A/0M/1Q/11/VA111A0M1-Q11@11....
# KS821C03T-K11  [{'path': 'KS/82/1C/03/TK/11/KS821C03T-K11@25....
# AX911N02H-O11  [{'path': 'AX/91/1N/02/HO/11/AX911N02H-O11@5.j...
# ON321A10V-C11  [{'path': 'ON/32/1A/10/VC/11/ON321A10V-C11@4.j...
#
#                                                             name outfits  \
# sku
# JY121I0AI-K11  JDYMAX LONG - Pullover - cloud dancer/dark den...     NaN
# UG111X01X-N11  CLASSIC MINI II - Boots à talons - eucalytpus ...     NaN
# TO151H0EB-Q11                                      Cabas - black     NaN
# NL021I0E6-Q11         LETTUCE EDGE STAND NECK - Pullover - black     NaN
# NI121J0AW-C11          Sweat à capuche - dark grey heather/white     NaN
# ...                                                          ...     ...
# C7641E034-Q11        CAPRI PANTS - Pantalon 3/4 de sport - black     NaN
# VA111A0M1-Q11              ZOE PLATFORM - Baskets basses - black     NaN
# KS821C03T-K11                             Robe d'été - night sky     NaN
# AX911N02H-O11          HIGHRISE - Bottines à talons hauts - rust     NaN
# ON321A10V-C11     ONLMIRINDA PANT - Pantalon classique - phantom     NaN
#
#               price.base_price  price.has_different_original_prices  \
# sku
# JY121I0AI-K11              NaN                                False
# UG111X01X-N11              NaN                                False
# TO151H0EB-Q11              NaN                                False
# NL021I0E6-Q11              NaN                                False
# NI121J0AW-C11              NaN                                False
# ...                        ...                                  ...
# C7641E034-Q11              NaN                                False
# VA111A0M1-Q11              NaN                                False
# KS821C03T-K11              NaN                                False
# AX911N02H-O11              NaN                                False
# ON321A10V-C11              NaN                                False
#
#                price.has_different_prices  \
# sku
# JY121I0AI-K11                       False
# UG111X01X-N11                       False
# TO151H0EB-Q11                       False
# NL021I0E6-Q11                       False
# NI121J0AW-C11                        True
# ...                                   ...
# C7641E034-Q11                       False
# VA111A0M1-Q11                       False
# KS821C03T-K11                       False
# AX911N02H-O11                       False
# ON321A10V-C11                       False
#
#                price.has_different_promotional_prices  \
# sku
# JY121I0AI-K11                                   False
# UG111X01X-N11                                   False
# TO151H0EB-Q11                                   False
# NL021I0E6-Q11                                   False
# NI121J0AW-C11                                    True
# ...                                               ...
# C7641E034-Q11                                   False
# VA111A0M1-Q11                                   False
# KS821C03T-K11                                   False
# AX911N02H-O11                                   False
# ON321A10V-C11                                   False
#
#                price.has_discount_on_selected_sizes_only price.original  \
# sku
# JY121I0AI-K11                                      False        26,99 €
# UG111X01X-N11                                      False       169,95 €
# TO151H0EB-Q11                                      False        79,95 €
# NL021I0E6-Q11                                      False        23,99 €
# NI121J0AW-C11                                      False        48,95 €
# ...                                                  ...            ...
# C7641E034-Q11                                      False        24,95 €
# VA111A0M1-Q11                                      False        99,95 €
# KS821C03T-K11                                      False        95,00 €
# AX911N02H-O11                                      False        69,95 €
# ON321A10V-C11                                      False        39,99 €
#
#               price.promotional product_group  \
# sku
# JY121I0AI-K11           21,59 €      clothing
# UG111X01X-N11          152,95 €          shoe
# TO151H0EB-Q11           63,95 €   accessoires
# NL021I0E6-Q11           20,39 €      clothing
# NI121J0AW-C11           41,55 €      clothing
# ...                         ...           ...
# C7641E034-Q11           16,15 €      clothing
# VA111A0M1-Q11           84,95 €          shoe
# KS821C03T-K11           66,50 €      clothing
# AX911N02H-O11           62,95 €          shoe
# ON321A10V-C11           25,99 €      clothing
#
#                                           sizes  \
# sku
# JY121I0AI-K11                     [XS, S, M, L]
# UG111X01X-N11  [36, 37, 38, 39, 40, 41, 42, 43]
# TO151H0EB-Q11                        [One Size]
# NL021I0E6-Q11          [34, 36, 38, 40, 42, 46]
# NI121J0AW-C11            [XS, S, M, L, XL, XXL]
# ...                                         ...
# C7641E034-Q11                       [XS, S, XL]
# VA111A0M1-Q11                  [36, 37, 40, 41]
# KS821C03T-K11                  [36, 40, 42, 44]
# AX911N02H-O11                [35, 40, 41, 42.5]
# ON321A10V-C11                    [36x32, 42x32]
#
#                                                          url_key
# sku
# JY121I0AI-K11             jdy-jdymax-long-pullover-jy121i0ai-k11
# UG111X01X-N11         ugg-classic-mini-ii-bottines-ug111x01x-n11
# TO151H0EB-Q11           tommy-hilfiger-cabas-black-to151h0eb-q11
# NL021I0E6-Q11  new-look-lettuce-edge-stand-neck-pullover-blac...
# NI121J0AW-C11    nike-sportswear-hoodie-sweatshirt-ni121j0aw-c11
# ...                                                          ...
# C7641E034-Q11  champion-capri-pants-collants-black-c7641e034-q11
# VA111A0M1-Q11  vagabond-zoe-platform-baskets-basses-black-va1...
# KS821C03T-K11  karen-by-simonsen-robe-dete-night-sky-ks821c03...
# AX911N02H-O11  call-it-spring-highrise-boots-a-talons-rust-ax...
# ON321A10V-C11  only-onlmirinda-pant-pantalon-classique-phanto...
#
# [74760 rows x 19 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df['discount_amount']
# Out:
# sku
# JY121I0AI-K11     5.4
# UG111X01X-N11    17.0
# TO151H0EB-Q11    16.0
# NL021I0E6-Q11     3.6
# NI121J0AW-C11     7.4
#                  ...
# C7641E034-Q11     8.8
# VA111A0M1-Q11    15.0
# KS821C03T-K11    28.5
# AX911N02H-O11     7.0
# ON321A10V-C11    14.0
# Name: discount_amount, Length: 74760, dtype: float64

# %%
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
# Trending brand:
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'myMo'

# %%
# This command is necessary to do the next exercise, because before the 'sku' name was like the index of the table
# and not a column to work with.
df1.reset_index()
# Out:
#                  sku amount         brand_name delivery_promises  \
# 0      JY121I0AI-K11    NaN                JDY                []
# 1      UG111X01X-N11    NaN                UGG                []
# 2      TO151H0EB-Q11    NaN     Tommy Hilfiger                []
# 3      NL021I0E6-Q11    NaN           New Look                []
# 4      NI121J0AW-C11    NaN    Nike Sportswear                []
# ...              ...    ...                ...               ...
# 74755  C7641E034-Q11    NaN           Champion                []
# 74756  VA111A0M1-Q11    NaN           Vagabond                []
# 74757  KS821C03T-K11    NaN  Karen by Simonsen                []
# 74758  AX911N02H-O11    NaN     Call it Spring                []
# 74759  ON321A10V-C11    NaN               ONLY                []
#
#       family_articles                                              flags  \
# 0                  []  [{'key': 'discountRate', 'value': '-20%', 'tra...
# 1                  []  [{'key': 'discountRate', 'value': '-10%', 'tra...
# 2                  []  [{'key': 'discountRate', 'value': '-20%', 'tra...
# 3                  []  [{'key': 'discountRate', 'value': '-15%', 'tra...
# 4                  []  [{'key': 'discountRate', 'value': 'Jusqu’à -15...
# ...               ...                                                ...
# 74755              []  [{'key': 'discountRate', 'value': '-35%', 'tra...
# 74756              []  [{'key': 'discountRate', 'value': '-15%', 'tra...
# 74757              []  [{'key': 'discountRate', 'value': '-30%', 'tra...
# 74758              []  [{'key': 'campaign', 'value': 'Végane', 'track...
# 74759              []  [{'key': 'discountRate', 'value': '-35%', 'tra...
#
#        is_premium                                              media  \
# 0           False  [{'path': 'JY/12/1I/0A/IK/11/JY121I0AI-K11@13....
# 1           False  [{'path': 'UG/11/1X/01/XN/11/UG111X01X-N11@6.j...
# 2           False  [{'path': 'TO/15/1H/0E/BQ/11/TO151H0EB-Q11@11....
# 3           False  [{'path': 'NL/02/1I/0E/6Q/11/NL021I0E6-Q11@4.j...
# 4           False  [{'path': 'NI/12/1J/0A/WC/11/NI121J0AW-C11@4.j...
# ...           ...                                                ...
# 74755       False  [{'path': 'C7/64/1E/03/4Q/11/C7641E034-Q11@4.j...
# 74756       False  [{'path': 'VA/11/1A/0M/1Q/11/VA111A0M1-Q11@11....
# 74757       False  [{'path': 'KS/82/1C/03/TK/11/KS821C03T-K11@25....
# 74758       False  [{'path': 'AX/91/1N/02/HO/11/AX911N02H-O11@5.j...
# 74759       False  [{'path': 'ON/32/1A/10/VC/11/ON321A10V-C11@4.j...
#
#                                                     name outfits  ...  \
# 0      JDYMAX LONG - Pullover - cloud dancer/dark den...     NaN  ...
# 1      CLASSIC MINI II - Boots à talons - eucalytpus ...     NaN  ...
# 2                                          Cabas - black     NaN  ...
# 3             LETTUCE EDGE STAND NECK - Pullover - black     NaN  ...
# 4              Sweat à capuche - dark grey heather/white     NaN  ...
# ...                                                  ...     ...  ...
# 74755        CAPRI PANTS - Pantalon 3/4 de sport - black     NaN  ...
# 74756              ZOE PLATFORM - Baskets basses - black     NaN  ...
# 74757                             Robe d'été - night sky     NaN  ...
# 74758          HIGHRISE - Bottines à talons hauts - rust     NaN  ...
# 74759     ONLMIRINDA PANT - Pantalon classique - phantom     NaN  ...
#
#       price.has_different_original_prices  price.has_different_prices  \
# 0                                   False                       False
# 1                                   False                       False
# 2                                   False                       False
# 3                                   False                       False
# 4                                   False                        True
# ...                                   ...                         ...
# 74755                               False                       False
# 74756                               False                       False
# 74757                               False                       False
# 74758                               False                       False
# 74759                               False                       False
#
#        price.has_different_promotional_prices  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                        True
# ...                                       ...
# 74755                                   False
# 74756                                   False
# 74757                                   False
# 74758                                   False
# 74759                                   False
#
#        price.has_discount_on_selected_sizes_only  price.original  \
# 0                                          False           26.99
# 1                                          False          169.95
# 2                                          False           79.95
# 3                                          False           23.99
# 4                                          False           48.95
# ...                                          ...             ...
# 74755                                      False           24.95
# 74756                                      False           99.95
# 74757                                      False           95.00
# 74758                                      False           69.95
# 74759                                      False           39.99
#
#       price.promotional product_group                             sizes  \
# 0                 21.59      clothing                     [XS, S, M, L]
# 1                152.95          shoe  [36, 37, 38, 39, 40, 41, 42, 43]
# 2                 63.95   accessoires                        [One Size]
# 3                 20.39      clothing          [34, 36, 38, 40, 42, 46]
# 4                 41.55      clothing            [XS, S, M, L, XL, XXL]
# ...                 ...           ...                               ...
# 74755             16.15      clothing                       [XS, S, XL]
# 74756             84.95          shoe                  [36, 37, 40, 41]
# 74757             66.50      clothing                  [36, 40, 42, 44]
# 74758             62.95          shoe                [35, 40, 41, 42.5]
# 74759             25.99      clothing                    [36x32, 42x32]
#
#                                                  url_key discount_amount
# 0                 jdy-jdymax-long-pullover-jy121i0ai-k11             5.4
# 1             ugg-classic-mini-ii-bottines-ug111x01x-n11            17.0
# 2               tommy-hilfiger-cabas-black-to151h0eb-q11            16.0
# 3      new-look-lettuce-edge-stand-neck-pullover-blac...             3.6
# 4        nike-sportswear-hoodie-sweatshirt-ni121j0aw-c11             7.4
# ...                                                  ...             ...
# 74755  champion-capri-pants-collants-black-c7641e034-q11             8.8
# 74756  vagabond-zoe-platform-baskets-basses-black-va1...            15.0
# 74757  karen-by-simonsen-robe-dete-night-sky-ks821c03...            28.5
# 74758  call-it-spring-highrise-boots-a-talons-rust-ax...             7.0
# 74759  only-onlmirinda-pant-pantalon-classique-phanto...            14.0
#
# [74760 rows x 21 columns]

# %%
# The product(s) with the highest discount in euros:
df1.groupby(['sku']).sum().discount_amount.sort_values(ascending=False).head()
# Out:
# sku
# MT021U00X-O11    796.0
# 23B21U00L-Q11    780.0
# NOE21U005-B11    680.0
# C7311X007-C11    465.0
# MQ121B00K-Q11    450.0
# Name: discount_amount, dtype: float64

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices):
df['sum_discounts'] = df['price.promotional'].astype(float).sum() / df['price.original'].astype(float).sum()
df['sum_discounts']
# Out:
# sku
# JY121I0AI-K11    0.727879
# UG111X01X-N11    0.727879
# TO151H0EB-Q11    0.727879
# NL021I0E6-Q11    0.727879
# NI121J0AW-C11    0.727879
#                    ...
# C7641E034-Q11    0.727879
# VA111A0M1-Q11    0.727879
# KS821C03T-K11    0.727879
# AX911N02H-O11    0.727879
# ON321A10V-C11    0.727879
# Name: sum_discounts, Length: 74760, dtype: float64

# %%
# To have the percentage of the sum of discounts of all goods, it's like the mean:
(df['sum_discounts']*100).value_counts()
# Out:
# 72.787866    74760
# Name: sum_discounts, dtype: int64
