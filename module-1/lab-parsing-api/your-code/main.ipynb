# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0"}

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %%
response = requests.get(url, headers=headers)
results = response.json()
results
# Out:
# {'total_count': 121036,
#  'pagination': {'page_count': 892, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'NI111A0E5-Q12',
#    'name': 'AIR MAX DIA - Baskets basses - black/metallic platinum',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '101,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5'],
#    'url_key': 'nike-sportswear-air-max-dia-baskets-basses-ni111a0e5-q12',
#    'media': [{'path': 'NI/11/1A/0E/5Q/12/NI111A0E5-Q12@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA215B000-Q12',
#    'name': 'OLD SKOOL - Chaussures de skate - black',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '67,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '47',
#     '48',
#     '49',
#     '50'],
#    'url_key': 'vans-old-skool-baskets-basses-va215b000-q12',
#    'media': [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD121A0AE-Q11',
#    'name': 'ADICOLOR TREFOIL TIGHT - Legging - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '22,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-trefoil-tight-legging-ad121a0ae-q11',
#    'media': [{'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'V1021A0GF-Q11',
#    'name': 'Pantalon classique - black',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '29,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44'],
#    'url_key': 'vila-viloan-78-pant-pantalon-classique-black-v1021a0gf-q11',
#    'media': [{'path': 'V1/02/1A/0G/FQ/11/V1021A0GF-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'V1/02/1A/0G/FQ/11/V1021A0GF-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI121D0EG-Q11',
#    'name': 'TEE ICON - T-shirt à manches longues - black/white',
#    'price': {'original': '28,95\xa0€',
#     'promotional': '23,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-tee-icon-t-shirt-a-manches-longues-blackwhite-ni121d0eg-q11',
#    'media': [{'path': 'NI/12/1D/0E/GQ/11/NI121D0EG-Q11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1D/0E/GQ/11/NI121D0EG-Q11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'NI114D0CK-Q11',
#    'name': 'Baskets basses - black',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-court-borough-baskets-basses-ni114d0ck-q11',
#    'media': [{'path': 'NI/11/4D/0C/KQ/11/NI114D0CK-Q11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TW421A03G-G11',
#    'name': 'Chino - dark red',
#    'price': {'original': '23,99\xa0€',
#     'promotional': '16,75\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '44', '46'],
#    'url_key': 'twintip-chino-dark-red-tw421a03g-g11',
#    'media': [{'path': 'TW/42/1A/03/GG/11/TW421A03G-G11@14.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TW/42/1A/03/GG/11/TW421A03G-G11@13.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'TWINTIP',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI111A0IT-A11',
#    'name': 'TEKNO  - Baskets basses - white/metallic silver/black',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43'],
#    'url_key': 'nike-sportswear-tekno-baskets-basses-ni111a0it-a11',
#    'media': [{'path': 'NI/11/1A/0I/TA/11/NI111A0IT-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'ST311M00V-Q11',
#    'name': 'ISAAC - Cuissardes - black',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '81,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'steve-madden-bottes-black-st311m00v-q11',
#    'media': [{'path': 'ST/31/1M/00/VQ/11/ST311M00V-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Steve Madden',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'tGTyWbSES0S',
#      'url_key': '/outfits/tGTyWbSES0S',
#      'media': [{'path': 'eafe0adcfa2040979e42c180df1360fb/277d8ce8562e448caeb512dabacb4bb0.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'f6dfabdd-0bc8-407a-b326-cae282c9d90b',
#       'name': 'hoardoftrends',
#       'media': [{'path': '4e89f67719da4bb2b718db7578698646/e1761ab18f094c7aac40feefeff5b34a.jpeg',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'UNK21G00D-I11'},
#       {'id': 'MOQ21D02X-M11'},
#       {'id': 'TP751H0L4-M11'},
#       {'id': 'MOQ21B01C-Q11'},
#       {'id': 'ST311M00V-Q11'}]}],
#    'delivery_promises': []},
#   {'sku': 'H0421D052-Q11',
#    'name': 'CORE  - Polo - black',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '12,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'hollister-co-core-polo-black-h0421d052-q11',
#    'media': [{'path': 'H0/42/1D/05/2Q/11/H0421D052-Q11@17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'H0/42/1D/05/2Q/11/H0421D052-Q11@13.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Hollister Co.',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'EV421N054-K11',
#    'name': 'Jeans Skinny - dark blue denim',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '14,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44'],
#    'url_key': 'evenandodd-jeans-skinny-dark-blue-denim-ev421n054-k11',
#    'media': [{'path': 'EV/42/1N/05/4K/11/EV421N054-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1N/05/4K/11/EV421N054-K11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'NI121J0AX-I11',
#    'name': 'HOODIE - Sweat à capuche - lavender mist/white',
#    'price': {'original': '48,95\xa0€',
#     'promotional': '44,05\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-hoodie-sweatshirt-ni121j0ax-i11',
#    'media': [{'path': 'NI/12/1J/0A/XI/11/NI121J0AX-I11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1J/0A/XI/11/NI121J0AX-I11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'DP511N08V-Q11',
#    'name': 'ASTRID HEEL ZIP - Boots à talons - black',
#    'price': {'original': '49,99\xa0€',
#     'promotional': '24,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'dorothy-perkins-astrid-heel-zip-boots-a-talons-black-dp511n08v-q11',
#    'media': [{'path': 'DP/51/1N/08/VQ/11/DP511N08V-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Dorothy Perkins',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD111A0Q7-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/gold metallic',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitegold-metallic-ad111a0q7-a11',
#    'media': [{'path': 'AD/11/1A/0Q/7A/11/AD111A0Q7-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LE221J00U-C11',
#    'name': 'GRAPHIC SPORT - Sweat à capuche - smokestack heather',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '48,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'levisr-graphic-sport-sweatshirt-smokestack-heather-le221j00u-c11',
#    'media': [{'path': 'LE/22/1J/00/UC/11/LE221J00U-C11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1J/00/UC/11/LE221J00U-C11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VE121D19W-M11',
#    'name': 'VMCELENA - T-shirt à manches longues - ponderosa pine',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '18,69\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL'],
#    'url_key': 'vero-moda-vmcelena-t-shirt-a-manches-longues-ve121d19w-m11',
#    'media': [{'path': 'VE/12/1D/19/WM/11/VE121D19W-M11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1D/19/WM/11/VE121D19W-M11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'EL921J00Y-Q11',
#    'name': 'TORICES - Sweat à capuche - black',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '46,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38', '40', '42', '44', '46'],
#    'url_key': 'ellesse-torices-sweatshirt-el921j00y-q11',
#    'media': [{'path': 'EL/92/1J/00/YQ/11/EL921J00Y-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EL/92/1J/00/YQ/11/EL921J00Y-Q11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Ellesse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TP721E0RD-T11',
#    'name': 'DITSY SHIRRED SMOCK - Blouse - multi',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '19,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40'],
#    'url_key': 'topshop-ditsy-shirred-smock-blouse-multi-tp721e0rd-t11',
#    'media': [{'path': 'TP/72/1E/0R/DT/11/TP721E0RD-T11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TP/72/1E/0R/DT/11/TP721E0RD-T11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Topshop',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE221D07C-K11',
#    'name': 'PERFECT V NECK - T-shirt imprimé - sea captain blue',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '17,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'levisr-perfect-v-neck-t-shirt-imprime-sea-captain-blue-le221d07c-k11',
#    'media': [{'path': 'LE/22/1D/07/CK/11/LE221D07C-K11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1D/07/CK/11/LE221D07C-K11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VE121C1AK-K11',
#    'name': 'Robe en jean - light blue denim',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '25,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'vero-moda-robe-en-jean-light-blue-denim-ve121c1ak-k11',
#    'media': [{'path': 'VE/12/1C/1A/KK/11/VE121C1AK-K11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1C/1A/KK/11/VE121C1AK-K11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'RE021D01N-K11',
#    'name': 'CROP TEE - T-shirt imprimé - collegiate navy',
#    'price': {'original': '23,95\xa0€',
#     'promotional': '14,35\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'reebok-classic-crop-tee-t-shirt-imprime-collegiate-navy-re021d01n-k11',
#    'media': [{'path': 'RE/02/1D/01/NK/11/RE021D01N-K11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'RE/02/1D/01/NK/11/RE021D01N-K11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Reebok Classic',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'EV421N053-Q11',
#    'name': 'Jeans Skinny - washed black',
#    'price': {'original': '26,99\xa0€',
#     'promotional': '13,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44'],
#    'url_key': 'evenandodd-jeans-skinny-washed-black-ev421n053-q11',
#    'media': [{'path': 'EV/42/1N/05/3Q/11/EV421N053-Q11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1N/05/3Q/11/EV421N053-Q11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': [{'key': 'fast_delivery_flag',
#      'label': 'Livré avant Noël',
#      'media_key': 'fast_delivery_flag'}]},
#   {'sku': 'DP511N084-Q11',
#    'name': 'MINA TIPPED JODPHUR - Boots à talons - black',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '29,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40'],
#    'url_key': 'dorothy-perkins-mina-tipped-jodphur-boots-a-talons-dp511n084-q11',
#    'media': [{'path': 'DP/51/1N/08/4Q/11/DP511N084-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Dorothy Perkins',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI112O093-H11',
#    'name': 'SIGNAL D/MS/X - Baskets basses - guava ice/light aqua/hyper crimson/blue hero/cedar/black',
#    'price': {'original': '124,95\xa0€',
#     'promotional': '61,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-signal-dmsx-baskets-basses-ni112o093-h11',
#    'media': [{'path': 'NI/11/2O/09/3H/11/NI112O093-H11@9.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'NI/11/2O/09/3H/11/NI112O093-H11@19.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'FAA21I01Y-Q11',
#    'name': 'BIRCH - Pullover - nude/black',
#    'price': {'original': '32,99\xa0€',
#     'promotional': '27,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34', '36', '38', '40', '42'],
#    'url_key': 'fashion-union-birch-pullover-nudeblack-faa21i01y-q11',
#    'media': [{'path': 'FA/A2/1I/01/YQ/11/FAA21I01Y-Q11@14.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'FA/A2/1I/01/YQ/11/FAA21I01Y-Q11@12.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fashion Union',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI121A08U-Q11',
#    'name': 'NSW LEGASEE 7/8 FUTURA - Legging - black/white',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '25,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-nsw-legasee-78-futura-legging-blackwhite-ni121a08u-q11',
#    'media': [{'path': 'NI/12/1A/08/UQ/11/NI121A08U-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1A/08/UQ/11/NI121A08U-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI111A0D1-A11',
#    'name': 'Baskets basses - white/black',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '76,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-zoom-2k-baskets-basses-ni111a0d1-a11',
#    'media': [{'path': 'NI/11/1A/0D/1A/11/NI111A0D1-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'EL921D02J-G11',
#    'name': 'GIGANTO - T-shirt à manches longues - red',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '33,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38', '40', '42', '44', '46'],
#    'url_key': 'ellesse-giganto-t-shirt-a-manches-longues-red-el921d02j-g11',
#    'media': [{'path': 'EL/92/1D/02/JG/11/EL921D02J-G11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EL/92/1D/02/JG/11/EL921D02J-G11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Ellesse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE221U00L-K11',
#    'name': 'SHERPA TRUCKER - Veste mi-saison - vintage navy blazer',
#    'price': {'original': '139,95\xa0€',
#     'promotional': '90,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M'],
#    'url_key': 'levisr-sherpa-trucker-veste-mi-saison-vintage-navy-blazer-le221u00l-k11',
#    'media': [{'path': 'LE/22/1U/00/LK/11/LE221U00L-K11@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1U/00/LK/11/LE221U00L-K11@18.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TA111A1F8-Q11',
#    'name': 'Bottes - black',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '101,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40', '41'],
#    'url_key': 'tamaris-bottes-black-ta111a1f8-q11',
#    'media': [{'path': 'TA/11/1A/1F/8Q/11/TA111A1F8-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Tamaris',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA211S03A-Q11',
#    'name': 'UA OLD SKOOL PLATFORM - Baskets basses - black/white',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '71,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43'],
#    'url_key': 'vans-baskets-basses-blackwhite-va211s03a-q11',
#    'media': [{'path': 'VA/21/1S/03/AQ/11/VA211S03A-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'a8XchmKJSoa',
#      'url_key': '/outfits/a8XchmKJSoa',
#      'media': [{'path': '2e1307635e394e40b6192429694fe786/6745161ecc15411faa6737cdd956c283.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'SPG31K00E-S11'},
#       {'id': 'EDD21U00C-J11'},
#       {'id': 'QX721D00Z-A11'},
#       {'id': 'QX721N008-K13'},
#       {'id': 'VA211S03A-Q11'},
#       {'id': 'EV451H0M7-Q11'},
#       {'id': '1SN51E00T-D11'}]}],
#    'delivery_promises': []},
#   {'sku': 'VA651D09T-F11',
#    'name': 'Ceinture taille haute - gold',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '34,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['M', 'L'],
#    'url_key': 'vanzetti-ceinture-gold-va651d09t-f11',
#    'media': [{'path': 'VA/65/1D/09/TF/11/VA651D09T-F11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VA/65/1D/09/TF/11/VA651D09T-F11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vanzetti',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NI121D0EG-A11',
#    'name': 'TEE ICON - T-shirt à manches longues - white/black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-tee-icon-t-shirt-a-manches-longues-ni121d0eg-a11',
#    'media': [{'path': 'NI/12/1D/0E/GA/11/NI121D0EG-A11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1D/0E/GA/11/NI121D0EG-A11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI121J0B8-Q11',
#    'name': 'HOODIE - veste en sweat zippée - black/white',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '43,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-hoodie-veste-en-sweat-zippee-blackwhite-ni121j0b8-q11',
#    'media': [{'path': 'NI/12/1J/0B/8Q/11/NI121J0B8-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1J/0B/8Q/11/NI121J0B8-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AN611NA3K-Q11',
#    'name': 'Bottines à talons hauts - black',
#    'price': {'original': '49,99\xa0€',
#     'promotional': '39,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38', '39', '40', '41', '42'],
#    'url_key': 'anna-field-boots-a-talons-black-an611na3k-q11',
#    'media': [{'path': 'AN/61/1N/A3/KQ/11/AN611NA3K-Q11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AN611N050-Q11',
#    'name': 'Bottines - black',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '35,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40', '41'],
#    'url_key': 'anna-field-bottines-black-an611n050-q11',
#    'media': [{'path': 'AN/61/1N/05/0Q/11/AN611N050-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD115B01Y-A11',
#    'name': 'SUPERSTAR - Baskets basses - white/core black',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '50',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3',
#     '50 2/3',
#     '51 1/3',
#     '52 2/3',
#     '53 1/3',
#     '54 2/3',
#     '55 2/3'],
#    'url_key': 'adidas-originals-baskets-basses-white-core-black-ad115b01y-a11',
#    'media': [{'path': 'AD/11/5B/01/YA/11/AD115B01Y-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TO151D01M-Q11',
#    'name': 'DANNY BELT - Ceinture - masters black',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['70', '75', '80', '85', '90', '95'],
#    'url_key': 'tommy-hilfiger-denny-ceinture-noir-to151d01m-q11',
#    'media': [{'path': 'TO/15/1D/01/MQ/11/TO151D01M-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/15/1D/01/MQ/11/TO151D01M-Q11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NI111A0E5-A14',
#    'name': 'AIR MAX DIA - Baskets basses - white/metalic platinum',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '95,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43'],
#    'url_key': 'nike-sportswear-air-max-dia-baskets-basses-ni111a0e5-a14',
#    'media': [{'path': 'NI/11/1A/0E/5A/14/NI111A0E5-A14@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'DLtQyx0jSv2',
#      'url_key': '/outfits/DLtQyx0jSv2',
#      'media': [{'path': '21c8a781e43f4d87abb9792d8d1741f5/3b5294f92a5847b38403186904d67ec9.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'OP631F00K-S11'},
#       {'id': 'TP721U06F-E11'},
#       {'id': 'WEB21D03Q-A11'},
#       {'id': 'PE121N0HL-K11'},
#       {'id': 'NI111A0E5-A14'},
#       {'id': 'AD111A0Q6-A11'},
#       {'id': 'ER751L08Q-F11'}]}],
#    'delivery_promises': []},
#   {'sku': 'N0B29A02N-Q11',
#    'name': 'Jean slim - black',
#    'price': {'original': '28,99\xa0€',
#     'promotional': '24,59\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36x32', '38x32', '40x32', '42x32', '44x32', '46x32'],
#    'url_key': 'new-look-maternity-jean-slim-black-n0b29a02n-q11',
#    'media': [{'path': 'N0/B2/9A/02/NQ/11/N0B29A02N-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'N0/B2/9A/02/NQ/11/N0B29A02N-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'New Look Maternity',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'assortmentArea',
#      'value': 'Maternité',
#      'tracking_value': 'maternity'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PE121N0CL-K12',
#    'name': 'VENUS - Jean droit - denim',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['24x30',
#     '24x32',
#     '24x34',
#     '25x30',
#     '25x32',
#     '25x34',
#     '26x30',
#     '26x32',
#     '27x30',
#     '27x32',
#     '27x34',
#     '28x30',
#     '28x32',
#     '28x34',
#     '29x30',
#     '29x32',
#     '30x32',
#     '31x30',
#     '31x32',
#     '32x30',
#     '32x32',
#     '32x34',
#     '33x30',
#     '33x32',
#     '33x34',
#     '34x30',
#     '34x32'],
#    'url_key': 'pepe-jeans-venus-jean-droit-pe121n0cl-k12',
#    'media': [{'path': 'PE/12/1N/0C/LK/12/PE121N0CL-K12@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'PE/12/1N/0C/LK/12/PE121N0CL-K12@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Pepe Jeans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'M0Q21N06O-Q11',
#    'name': 'VICE BUTTON UP WITH ANKLE ZIP - Jeans Skinny - black',
#    'price': {'original': '33,99\xa0€',
#     'promotional': '16,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34', '36', '38', '40', '42'],
#    'url_key': 'missguided-vice-button-up-with-ankle-zip-jeans-skinny-black-m0q21n06o-q11',
#    'media': [{'path': 'M0/Q2/1N/06/OQ/11/M0Q21N06O-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'M0/Q2/1N/06/OQ/11/M0Q21N06O-Q11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Missguided',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JY121G019-Q11',
#    'name': 'JDYNEW BRIGHTON SPRING COAT - Manteau court - black',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '31,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'jdy-jdynew-brighton-spring-coat-manteau-classique-black-jy121g019-q11',
#    'media': [{'path': 'JY/12/1G/01/9Q/11/JY121G019-Q11@15.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'JY/12/1G/01/9Q/11/JY121G019-Q11@17.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'JDY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD115O0BS-A14',
#    'name': 'STAN SMITH STREETWEAR-STYLE SHOES - Baskets basses - footware white/trace cargo',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-ad115o0bs-a14',
#    'media': [{'path': 'AD/11/5O/0B/SA/14/AD115O0BS-A14@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
# ...
#      'is_family': False},
#     {'key': 'OD1', 'label': 'ODLO', 'is_family': False},
#     {'key': 'OF00', 'label': 'Office', 'is_family': True},
#     ...],
#    'family_key': 'brand_families'},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4.49,
#     'max': 1523.95,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Soldes',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les Promos'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'OTHER', 'label': 'Autres matières'},
#     {'key': 'CASHMERE', 'label': 'Cachemire'},
#     {'key': 'CAOUTCHOUC', 'label': 'Caoutchouc'},
#     {'key': 'COTTON', 'label': 'Coton'},
#     {'key': 'CROCHETED', 'label': 'Crocheté'},
#     {'key': 'LEATHER', 'label': 'Cuir'},
#     {'key': 'CORD', 'label': 'Côtelé'},
#     {'key': 'DENIM', 'label': 'Denim'},
#     {'key': 'LACE', 'label': 'Dentelle'},
#     {'key': 'FELT', 'label': 'Feutre'},
#     {'key': 'FLANELETTE', 'label': 'Flanelle chaude'},
#     {'key': 'HARDSHELL', 'label': 'Hardshell'},
#     {'key': 'IMITATION_LEATHER', 'label': 'Imitation cuir'},
#     {'key': 'JERSEY', 'label': 'Jersey'},
#     {'key': 'WOOL', 'label': 'Laine'},
#     {'key': 'LINEN', 'label': 'Lin'},
#     {'key': 'MESH', 'label': 'Mesh'},
#     {'key': 'FEATHERS', 'label': 'Plume'},
#     {'key': 'FLEECE', 'label': 'Polaire'},
#     {'key': 'POLYESTER', 'label': 'Polyester'},
#     {'key': 'SATIN', 'label': 'Satin'},
#     {'key': 'SOFTSHELL', 'label': 'Softshell'},
#     {'key': 'SILK', 'label': 'Soie'},
#     {'key': 'RIB', 'label': 'Strié'},
#     {'key': 'SWEAT', 'label': 'Sweat'},
#     {'key': 'SYNTHETIC', 'label': 'Synthétique'},
#     {'key': 'TEXTILE', 'label': 'Textile'},
#     {'key': 'BRAIDED', 'label': 'tressé'},
#     {'key': 'VARNISH', 'label': 'Verni'},
#     {'key': 'VISCOSE', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}],
#    'group_id': 'sustainable'},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'STRIPED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'POLKA_DOT', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'PETITE', 'label': 'Petite'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'fr_aw19_fresh_days_2019_49', 'label': '-20% EXTRA'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'vegan',
#    'label': 'Végane',
#    'url_key': 'vegan',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Végane'}],
#    'group_id': 'vegan'}],
#  'total_article_count': 121056,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promos',
#    'id': '8803',
#    'url_key': 'promo-femme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-femme/',
#    'children': [{'label': 'Vêtements',
#      'id': '8838',
#      'url_key': 'promo-mode-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-femme/',
#      'children': [],
#      'article_count': 76772},
#     {'label': 'Chaussures',
#      'id': '8804',
#      'url_key': 'promo-chaussures-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-femme/',
#      'children': [],
#      'article_count': 29637},
#     {'label': 'Sacs et accessoires',
#      'id': '8860',
#      'url_key': 'promo-accessoires-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-femme/',
#      'children': [],
#      'article_count': 13261},
#     {'label': 'Lingerie',
#      'id': '8850',
#      'url_key': 'promo-lingerie-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-lingerie-femme/',
#      'children': [],
#      'article_count': 6266},
#     {'label': 'Luxe',
#      'id': '13429',
#      'url_key': 'promo-luxe-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-femme/',
#      'children': [],
#      'article_count': 9053},
#     {'label': 'Sport',
#      'id': '13286',
#      'url_key': 'promo-sport-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-femme/',
#      'children': [],
#      'article_count': 8091},
#     {'label': 'Beauté',
#      'id': '13478',
#      'url_key': 'beaute-femme-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-femme-promo/',
#      'children': [],
#      'article_count': 1222}],
#    'article_count': 121042}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Femme',
#      'url_key': 'femme',
#      'full_url': '/femme/'},
#     {'label': 'Promos',
#      'url_key': 'promo-femme',
#      'full_url': '/promo-femme/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-femme',
#       'url_key': 'promo-femme',
#       'label': 'Promos',
#       'seo_label': 'Promotions femme',
#       'reset_url': '/',
#       'id': '8803'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-femme/',
#   'reset_url': '/promo-femme/',
#   'app_url': '?urlKey=promo-femme&order=popularity&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-femme',
#     'url_key': 'promo-femme',
#     'label': 'Promos',
#     'seo_label': 'Promotions femme',
#     'reset_url': '/',
#     'id': '8803'}]},
#  'selectedFilters': {'categories': ['promo-femme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': 'Faire du shopping sans culpabiliser ? Avec nos promos pour femme, c’est possible ! Offrez-vous les incontournables de cette saison tels que le bomber XXL ou les loafers à prix réduit. Mais attention, ils partent vite !',
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/78b54c3c-0642-4175-a2ed-9e9249644545/93aab2d6-bfb5-4ea1-bc43-6c134502e3fb/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=7070cb8e-c8a0-4dae-9073-61f0241800bf&timeUnit=null&timeUnitCount=null&uuid=3c0d2a69-77d6-4ec3-bae0-52650455446e&bid=null&requestId=885581f4-0597-45ed-8649-7082690783ad&s=E3BA41C50206338E8FC7EEFFEEBADFD3'],
#    'images': [{'aspect_ratio': None,
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/3200/549/3500/spp-media-p1/8ed70eb91494454fb50c43eaa45e2e2a/217af45f5f5f46bb8f1cf36a73d444e5.jpeg',
#      'image_width': None},
#     {'aspect_ratio': None,
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/480/555/960/819/750/spp-media-p1/67c552c0d4bd41ebb242fd8a8fd5a87f/4f4550cdb7994842b0acdb1783e7c298.jpeg',
#      'image_width': None}],
#    'creative_id': '7070cb8e-c8a0-4dae-9073-61f0241800bf',
#    'campaign_id': '78b54c3c-0642-4175-a2ed-9e9249644545',
#    'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#    'campaign_source_id': 'RQsmB4tXTAC',
#    'text_fields': {'cta': "J'en profite",
#     'bg_color': '#940000',
#     'legal_claim': "*Offre valable jusqu'au 17/12/2019 à 23h59 sur les articles soldés et les prix minis, à partir de 90€ d'achat.",
#     'voucher_code': 'STAYFRESH',
#     'title': "JUSQU'À -50% ET -20% EXTRA",
#     'type': 'sales',
#     'sales_template': 'Voucher',
#     'byline': 'Juste à temps pour Noël ⏰',
#     'voucher_label': 'Code promo*'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#       'brand_code': '-1',
#       'billing_method': 'CPV',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': '5doJCaNM-rFULhRO',
#       'price': 0.010811299064261115,
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'RQsmB4tXTAC',
#       'request_id': '885581f4-0597-45ed-8649-7082690783ad',
#       'campaign_id': '78b54c3c-0642-4175-a2ed-9e9249644545',
#       'creative_id': '7070cb8e-c8a0-4dae-9073-61f0241800bf'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_slot_id': 'catalog',
#        'creative_id': '7070cb8e-c8a0-4dae-9073-61f0241800bf',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'adId': 'i00jHjcaTXq',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '5doJCaNM-rFULhRO',
#        'price': 0.010811299064261115,
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': '885581f4-0597-45ed-8649-7082690783ad',
#        'campaign_id': '78b54c3c-0642-4175-a2ed-9e9249644545'},
#       'dimension74': {'adId': 'i00jHjcaTXq'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_slot_id': 'catalog',
#        'creative_id': '7070cb8e-c8a0-4dae-9073-61f0241800bf',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'adId': 'i00jHjcaTXq',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '5doJCaNM-rFULhRO',
#        'price': 0.010811299064261115,
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': '885581f4-0597-45ed-8649-7082690783ad',
#        'campaign_id': '78b54c3c-0642-4175-a2ed-9e9249644545'},
#       'dimension74': {'adId': 'i00jHjcaTXq'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/78b54c3c-0642-4175-a2ed-9e9249644545/93aab2d6-bfb5-4ea1-bc43-6c134502e3fb/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=7070cb8e-c8a0-4dae-9073-61f0241800bf&timeUnit=null&timeUnitCount=null&uuid=7748aad2-1cb5-4353-8f93-003293bc7d76&bid=11&requestId=885581f4-0597-45ed-8649-7082690783ad&s=0C9A9530985AF282FB062FF94DFA7DEF'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': '5doJCaNM-rFULhRO',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'campaign_id': '78b54c3c-0642-4175-a2ed-9e9249644545',
#      'creative_id': '7070cb8e-c8a0-4dae-9073-61f0241800bf',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'brand_code': '-1',
#      'billing_method': 'CPV',
#      'shop_slot_id': 'catalog',
#      'creative_id': '7070cb8e-c8a0-4dae-9073-61f0241800bf',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'adId': 'i00jHjcaTXq',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': '5doJCaNM-rFULhRO',
#      'price': 0.010811299064261115,
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'request_id': '885581f4-0597-45ed-8649-7082690783ad',
#      'campaign_id': '78b54c3c-0642-4175-a2ed-9e9249644545'}},
#    'click_url': 'https://www.zalando.fr/promo-femme/?camp=fr_aw19_fresh_days_2019_49&sale=true'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)

# %%
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   NI111A0E5-Q12  AIR MAX DIA - Baskets basses - black/metallic ...
# 1   VA215B000-Q12            OLD SKOOL - Chaussures de skate - black
# 2   AD121A0AE-Q11           ADICOLOR TREFOIL TIGHT - Legging - black
# 3   V1021A0GF-Q11                         Pantalon classique - black
# 4   NI121D0EG-Q11  TEE ICON - T-shirt à manches longues - black/w...
# ..            ...                                                ...
# 79  JY121E0BE-Q11                                     Blouse - black
# 80  NI111A0FK-Q12  REACT ELEMENT 55 PRM - Baskets basses - black/...
# 81  NI111A0GI-A18  AIR MAX 200 - Baskets basses - white/black/ant...
# 82  TO721D0OP-K11        SOFT TEE - T-shirt imprimé - real navy blue
# 83  NI121J0BQ-Q11                      Sweat à capuche - black/white
#
#                                                 sizes  \
# 0   [36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5, 41, 4...
# 1   [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# 2                    [32, 34, 36, 38, 40, 42, 44, 46]
# 3                                [36, 38, 40, 42, 44]
# 4                                   [XS, S, M, L, XL]
# ..                                                ...
# 79                               [36, 38, 40, 42, 44]
# 80  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# 81  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# 82                                 [S, M, L, XL, XXL]
# 83                             [XS, S, M, L, XL, XXL]
#
#                                               url_key  \
# 0   nike-sportswear-air-max-dia-baskets-basses-ni1...
# 1         vans-old-skool-baskets-basses-va215b000-q12
# 2   adidas-originals-trefoil-tight-legging-ad121a0...
# 3   vila-viloan-78-pant-pantalon-classique-black-v...
# 4   nike-sportswear-tee-icon-t-shirt-a-manches-lon...
# ..                                                ...
# 79  jdy-jdyoda-v-neck-blouse-blouse-black-jy121e0b...
# 80  nike-sportswear-react-55-baskets-basses-ni111a...
# 81  nike-sportswear-air-max-200-baskets-basses-ni1...
# 82  tom-tailor-denim-soft-tee-t-shirt-imprime-real...
# 83  nike-sportswear-sweatshirt-blackwhite-ni121j0b...
#
#                                                 media        brand_name  \
# 0   [{'path': 'NI/11/1A/0E/5Q/12/NI111A0E5-Q12@11....   Nike Sportswear
# 1   [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12....              Vans
# 2   [{'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@11....  adidas Originals
# 3   [{'path': 'V1/02/1A/0G/FQ/11/V1021A0GF-Q11@7.j...              Vila
# 4   [{'path': 'NI/12/1D/0E/GQ/11/NI121D0EG-Q11@4.j...   Nike Sportswear
# ..                                                ...               ...
# 79  [{'path': 'JY/12/1E/0B/EQ/11/JY121E0BE-Q11@13....               JDY
# 80  [{'path': 'NI/11/1A/0F/KQ/12/NI111A0FK-Q12@21....   Nike Sportswear
# 81  [{'path': 'NI/11/1A/0G/IA/18/NI111A0GI-A18@27....   Nike Sportswear
# 82  [{'path': 'TO/72/1D/0O/PK/11/TO721D0OP-K11@14....  TOM TAILOR DENIM
# 83  [{'path': 'NI/12/1J/0B/QQ/11/NI121J0BQ-Q11@4.j...   Nike Sportswear
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 1   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 2   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 3   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 4   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 80  [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 81  [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 82  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 83  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
#
#                                     delivery_promises price.original  \
# 0                                                  []       119,95 €
# 1                                                  []        74,95 €
# 2                                                  []        29,95 €
# 3                                                  []        39,95 €
# 4   [{'key': 'fast_delivery_flag', 'label': 'Livré...        28,95 €
# ..                                                ...            ...
# 79                                                 []        21,99 €
# 80                                                 []       139,95 €
# 81                                                 []       124,95 €
# 82                                                 []        24,99 €
# 83                                                 []        49,95 €
#
#    price.promotional  price.has_different_prices  \
# 0           101,95 €                        True
# 1            67,45 €                       False
# 2            22,45 €                        True
# 3            29,99 €                       False
# 4            23,15 €                       False
# ..               ...                         ...
# 79           15,39 €                       False
# 80           83,95 €                        True
# 81           74,95 €                        True
# 82           14,99 €                        True
# 83           39,95 €                        True
#
#     price.has_different_original_prices  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 79                                False
# 80                                False
# 81                                False
# 82                                False
# 83                                False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                    True
# 81                                    True
# 82                                    True
# 83                                    True
#
#     price.has_discount_on_selected_sizes_only outfits
# 0                                       False     NaN
# 1                                       False     NaN
# 2                                       False     NaN
# 3                                       False     NaN
# 4                                       False     NaN
# ..                                        ...     ...
# 79                                      False     NaN
# 80                                      False     NaN
# 81                                      False     NaN
# 82                                      False     NaN
# 83                                      False     NaN
#
# [84 rows x 18 columns]

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']
total_pages
# Out:
# 892

# %%
df=pd.DataFrame()
for i in range(2, total_pages):
    k=84*i
    url = f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
    response = requests.get(url, headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

# %%
df.columns
# Out:
# Index(['amount', 'brand_name', 'delivery_promises', 'family_articles', 'flags',
#        'is_premium', 'media', 'name', 'outfits', 'price.base_price',
#        'price.has_different_original_prices', 'price.has_different_prices',
#        'price.has_different_promotional_prices',
#        'price.has_discount_on_selected_sizes_only', 'price.original',
#        'price.promotional', 'product_group', 'sizes', 'url_key'],
#       dtype='object')

# %%
display(df)
# Out:
#               amount       brand_name  \
# sku
# LE221D033-C11    NaN          Levi's®
# 1FI21A00Q-K11    NaN             Fila
# NI111A0EU-N11    NaN  Nike Sportswear
# TO211X016-K11    NaN       TOM TAILOR
# IC221A04T-N11    NaN             ICHI
# ...              ...              ...
# PC751A009-Q11    NaN             Opus
# BY221E04N-G11    NaN          b.young
# HU211B046-Q11    NaN             Högl
# M3W21E01I-Q11    NaN            Masai
# FIG11N004-Q11    NaN          Fitters
#
#                                                delivery_promises  \
# sku
# LE221D033-C11  [{'key': 'fast_delivery_flag', 'label': 'Livré...
# 1FI21A00Q-K11                                                 []
# NI111A0EU-N11                                                 []
# TO211X016-K11                                                 []
# IC221A04T-N11                                                 []
# ...                                                          ...
# PC751A009-Q11                                                 []
# BY221E04N-G11                                                 []
# HU211B046-Q11                                                 []
# M3W21E01I-Q11                                                 []
# FIG11N004-Q11                                                 []
#
#               family_articles  \
# sku
# LE221D033-C11              []
# 1FI21A00Q-K11              []
# NI111A0EU-N11              []
# TO211X016-K11              []
# IC221A04T-N11              []
# ...                       ...
# PC751A009-Q11              []
# BY221E04N-G11              []
# HU211B046-Q11              []
# M3W21E01I-Q11              []
# FIG11N004-Q11              []
#
#                                                            flags  is_premium  \
# sku
# LE221D033-C11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# 1FI21A00Q-K11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# NI111A0EU-N11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# TO211X016-K11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# IC221A04T-N11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# ...                                                          ...         ...
# PC751A009-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# BY221E04N-G11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# HU211B046-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# M3W21E01I-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
# FIG11N004-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...       False
#
#                                                            media  \
# sku
# LE221D033-C11  [{'path': 'LE/22/1D/03/3C/11/LE221D033-C11@8.j...
# 1FI21A00Q-K11  [{'path': '1F/I2/1A/00/QK/11/1FI21A00Q-K11@7.j...
# NI111A0EU-N11  [{'path': 'NI/11/1A/0E/UN/11/NI111A0EU-N11@7.j...
# TO211X016-K11  [{'path': 'TO/21/1X/01/6K/11/TO211X016-K11@3.j...
# IC221A04T-N11  [{'path': 'IC/22/1A/04/TN/11/IC221A04T-N11@8.j...
# ...                                                          ...
# PC751A009-Q11  [{'path': 'PC/75/1A/00/9Q/11/PC751A009-Q11@6.j...
# BY221E04N-G11  [{'path': 'BY/22/1E/04/NG/11/BY221E04N-G11@7.j...
# HU211B046-Q11  [{'path': 'HU/21/1B/04/6Q/11/HU211B046-Q11@11....
# M3W21E01I-Q11  [{'path': 'M3/W2/1E/01/IQ/11/M3W21E01I-Q11@16....
# FIG11N004-Q11  [{'path': 'FI/G1/1N/00/4Q/11/FIG11N004-Q11@8.j...
#
#                                                             name outfits  \
# sku
# LE221D033-C11               THE PERFECT - T-shirt imprimé - grey     NaN
# 1FI21A00Q-K11  EIDER PANTS - Pantalon de survêtement - black ...     NaN
# NI111A0EU-N11  AIR MAX 98 - Baskets basses - cargo khaki/blac...     NaN
# TO211X016-K11                                      Bottes - navy     NaN
# IC221A04T-N11        IXKATE - Pantalon de survêtement - kalamata     NaN
# ...                                                          ...     ...
# PC751A009-Q11                       ALEDA GLOVES - Gants - black     NaN
# BY221E04N-G11            BYGETAGAR BLOUSE - Blouse - dark copper     NaN
# HU211B046-Q11                   Escarpins à talons hauts - black     NaN
# M3W21E01I-Q11                      GRASSA TUNIC - Blouse - black     NaN
# FIG11N004-Q11                           KATTY - Bottines - black     NaN
#
#               price.base_price  price.has_different_original_prices  \
# sku
# LE221D033-C11              NaN                                False
# 1FI21A00Q-K11              NaN                                False
# NI111A0EU-N11              NaN                                False
# TO211X016-K11              NaN                                False
# IC221A04T-N11              NaN                                False
# ...                        ...                                  ...
# PC751A009-Q11              NaN                                False
# BY221E04N-G11              NaN                                False
# HU211B046-Q11              NaN                                False
# M3W21E01I-Q11              NaN                                False
# FIG11N004-Q11              NaN                                False
#
#                price.has_different_prices  \
# sku
# LE221D033-C11                       False
# 1FI21A00Q-K11                       False
# NI111A0EU-N11                       False
# TO211X016-K11                       False
# IC221A04T-N11                       False
# ...                                   ...
# PC751A009-Q11                       False
# BY221E04N-G11                       False
# HU211B046-Q11                       False
# M3W21E01I-Q11                       False
# FIG11N004-Q11                       False
#
#                price.has_different_promotional_prices  \
# sku
# LE221D033-C11                                   False
# 1FI21A00Q-K11                                   False
# NI111A0EU-N11                                   False
# TO211X016-K11                                   False
# IC221A04T-N11                                   False
# ...                                               ...
# PC751A009-Q11                                   False
# BY221E04N-G11                                   False
# HU211B046-Q11                                   False
# M3W21E01I-Q11                                   False
# FIG11N004-Q11                                   False
#
#                price.has_discount_on_selected_sizes_only price.original  \
# sku
# LE221D033-C11                                      False        24,95 €
# 1FI21A00Q-K11                                      False        48,95 €
# NI111A0EU-N11                                      False       169,95 €
# TO211X016-K11                                      False        69,99 €
# IC221A04T-N11                                      False        44,95 €
# ...                                                  ...            ...
# PC751A009-Q11                                      False        43,95 €
# BY221E04N-G11                                      False        29,95 €
# HU211B046-Q11                                      False       149,95 €
# M3W21E01I-Q11                                      False        89,95 €
# FIG11N004-Q11                                      False        59,95 €
#
#               price.promotional product_group  \
# sku
# LE221D033-C11           18,65 €      clothing
# 1FI21A00Q-K11           29,35 €      clothing
# NI111A0EU-N11          101,95 €          shoe
# TO211X016-K11           34,99 €          shoe
# IC221A04T-N11           29,15 €      clothing
# ...                         ...           ...
# PC751A009-Q11           28,55 €   accessoires
# BY221E04N-G11           16,45 €      clothing
# HU211B046-Q11          119,95 €          shoe
# M3W21E01I-Q11           44,95 €      clothing
# FIG11N004-Q11           53,95 €          shoe
#
#                                                            sizes  \
# sku
# LE221D033-C11                                      [XS, S, M, L]
# 1FI21A00Q-K11                                [XS, S, M, XL, XXL]
# NI111A0EU-N11  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# TO211X016-K11                       [36, 37, 38, 39, 40, 41, 42]
# IC221A04T-N11                                  [XS, S, M, L, XL]
# ...                                                          ...
# PC751A009-Q11                                                [S]
# BY221E04N-G11                                       [36, 38, 40]
# HU211B046-Q11             [35, 36, 37, 37.5, 38, 38.5, 39, 41.5]
# M3W21E01I-Q11                                         [XS, S, M]
# FIG11N004-Q11                                           [42, 45]
#
#                                                          url_key
# sku
# LE221D033-C11   levi-s-the-perfect-t-shirt-imprime-le221d033-c11
# 1FI21A00Q-K11  fila-eider-pants-pantalon-de-survetement-black...
# NI111A0EU-N11  nike-sportswear-air-max-98-baskets-basses-ni11...
# TO211X016-K11      tom-tailor-bottes-de-neige-navy-to211x016-k11
# IC221A04T-N11  ichi-ixkate-pantalon-de-survetement-kalamata-i...
# ...                                                          ...
# PC751A009-Q11        opus-aleda-gloves-gants-black-pc751a009-q11
# BY221E04N-G11  byoung-bygetagar-blouse-blouse-dark-copper-by2...
# HU211B046-Q11  hoegl-escarpins-a-plateforme-schwarz-hu211b046...
# M3W21E01I-Q11      masai-grassa-tunic-blouse-black-m3w21e01i-q11
# FIG11N004-Q11         fitters-katty-bottines-black-fig11n004-q11
#
# [74760 rows x 19 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
# Trending brand:
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'myMo'

# %%
# The product(s) with the highest discount:
df1['product_group'].groupby(df1['discount_amount']).value_counts(ascending=False)
# Out:
# discount_amount  product_group
# -848.0           clothing         1
# -798.0           clothing         1
# -773.0           clothing         1
# -765.0           clothing         1
# -761.0           clothing         1
#                                  ..
#  381.0           clothing         1
#  385.0           shoe             1
#  398.0           clothing         1
#  465.0           shoe             1
#  780.0           clothing         1
# Name: product_group, Length: 6375, dtype: int64

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices):
df['sum_discounts'] = df['price.promotional'].astype(float).sum() / df['price.original'].astype(float).sum()
df['sum_discounts']
# Out:
# sku
# LE221D033-C11    0.700511
# 1FI21A00Q-K11    0.700511
# NI111A0EU-N11    0.700511
# TO211X016-K11    0.700511
# IC221A04T-N11    0.700511
#                    ...
# PC751A009-Q11    0.700511
# BY221E04N-G11    0.700511
# HU211B046-Q11    0.700511
# M3W21E01I-Q11    0.700511
# FIG11N004-Q11    0.700511
# Name: sum_discounts, Length: 74760, dtype: float64

# %%
# To have the percentage of discounts:
(df['sum_discounts']*100).value_counts()
# Out:
# 70.051073    74760
# Name: sum_discounts, dtype: int64
