# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0"}

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %%
response = requests.get(url, headers=headers)
results = response.json()
results
# Out:
# {'total_count': 115491,
#  'pagination': {'page_count': 892, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': '5VA51D009-Q11',
#    'name': 'LADY - Ceinture - nero',
#    'price': {'original': '34,99\xa0€',
#     'promotional': '27,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L'],
#    'url_key': 'valentino-by-mario-valentino-lady-ceinture-nero-5va51d009-q11',
#    'media': [{'path': '5V/A5/1D/00/9Q/11/5VA51D009-Q11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': '5V/A5/1D/00/9Q/11/5VA51D009-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Valentino by Mario Valentino',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'VA215B000-Q12',
#    'name': 'OLD SKOOL - Chaussures de skate - black',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '67,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '47',
#     '48',
#     '49',
#     '50'],
#    'url_key': 'vans-old-skool-baskets-basses-va215b000-q12',
#    'media': [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'GS2rkdweTwu',
#      'url_key': '/outfits/GS2rkdweTwu',
#      'media': [{'path': 'cfb4ee75b7c14cf99c9a8d51e43fc423/d5bd6dac27bf4c41b7aa90648eff13ab.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'LUD31E003-S11'},
#       {'id': 'DP621G00X-N11'},
#       {'id': '2SW51L0B3-F11'},
#       {'id': 'Z1721A043-Q11'},
#       {'id': 'VA215B000-Q12'}]}],
#    'delivery_promises': []},
#   {'sku': 'UG111X03C-Q11',
#    'name': 'CLASSIC MINI LOGO - Bottes de neige - black',
#    'price': {'original': '169,95\xa0€',
#     'promotional': '135,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40', '41', '42', '43'],
#    'url_key': 'ugg-classic-mini-logo-bottes-de-neige-black-ug111x03c-q11',
#    'media': [{'path': 'UG/11/1X/03/CQ/11/UG111X03C-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'UGG',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0CK-Q11',
#    'name': 'Baskets basses - black',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '39', '40'],
#    'url_key': 'nike-sportswear-court-borough-baskets-basses-ni114d0ck-q11',
#    'media': [{'path': 'NI/11/4D/0C/KQ/11/NI114D0CK-Q11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI111A0IT-A11',
#    'name': 'TEKNO  - Baskets basses - white/metallic silver/black',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44'],
#    'url_key': 'nike-sportswear-tekno-baskets-basses-ni111a0it-a11',
#    'media': [{'path': 'NI/11/1A/0I/TA/11/NI111A0IT-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PU115O05D-K11',
#    'name': 'AXIS - Baskets basses - black/blue turquoise/castlerock/silver/high rise',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37.5',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '47'],
#    'url_key': 'puma-axis-baskets-basses-pu115o05d-k11',
#    'media': [{'path': 'PU/11/5O/05/DK/11/PU115O05D-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': '1FI21A00I-Q11',
#    'name': 'FLEX - Legging - black',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '31,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'fila-flex-legging-black-1fi21a00i-q11',
#    'media': [{'path': '1F/I2/1A/00/IQ/11/1FI21A00I-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': '1F/I2/1A/00/IQ/11/1FI21A00I-Q11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD115O0A9-Q11',
#    'name': 'CONTINENTAL VULC  - Baskets basses - coreblack/footwearwhite',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-continental-baskets-basses-ad115o0a9-q11',
#    'media': [{'path': 'AD/11/5O/0A/9Q/11/AD115O0A9-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD121A0AE-Q11',
#    'name': 'ADICOLOR TREFOIL TIGHT - Legging - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '22,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-trefoil-tight-legging-ad121a0ae-q11',
#    'media': [{'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD121A0AE-K12',
#    'name': 'ADICOLOR TREFOIL TIGHT - Legging - collegiate navy',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-trefoil-tight-legging-ad121a0ae-k12',
#    'media': [{'path': 'AD/12/1A/0A/EK/12/AD121A0AE-K12@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/0A/EK/12/AD121A0AE-K12@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VA221D09I-A11',
#    'name': 'TANGLE - T-shirt à manches longues - white',
#    'price': {'original': '37,95\xa0€',
#     'promotional': '22,75\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44'],
#    'url_key': 'vans-tangle-t-shirt-a-manches-longues-white-va221d09i-a11',
#    'media': [{'path': 'VA/22/1D/09/IA/11/VA221D09I-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VA/22/1D/09/IA/11/VA221D09I-A11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TOB21D05J-G11',
#    'name': 'CLEAN LINEAR LOGO LONGSLEEVE - T-shirt à manches longues - orchid bouquet',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '29,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'tommy-jeans-clean-linear-logo-longsleeve-t-shirt-a-manches-longues-tob21d05j-g11',
#    'media': [{'path': 'TO/B2/1D/05/JG/11/TOB21D05J-G11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/B2/1D/05/JG/11/TOB21D05J-G11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Jeans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE221J00U-C11',
#    'name': 'GRAPHIC SPORT - Sweat à capuche - smokestack heather',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '48,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'levisr-graphic-sport-sweatshirt-smokestack-heather-le221j00u-c11',
#    'media': [{'path': 'LE/22/1J/00/UC/11/LE221J00U-C11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1J/00/UC/11/LE221J00U-C11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NL021I0E3-Q11',
#    'name': 'LEAD INLONG LINE - Pullover - oche',
#    'price': {'original': '21,99\xa0€',
#     'promotional': '13,19\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L'],
#    'url_key': 'new-look-lead-inlong-line-pullover-oche-nl021i0e3-q11',
#    'media': [{'path': 'NL/02/1I/0E/3Q/11/NL021I0E3-Q11@22.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NL/02/1I/0E/3Q/11/NL021I0E3-Q11@23.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'New Look',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TP721E0RD-T11',
#    'name': 'DITSY SHIRRED SMOCK - Blouse - multi',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '19,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40'],
#    'url_key': 'topshop-ditsy-shirred-smock-blouse-multi-tp721e0rd-t11',
#    'media': [{'path': 'TP/72/1E/0R/DT/11/TP721E0RD-T11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TP/72/1E/0R/DT/11/TP721E0RD-T11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Topshop',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO721D0OP-K11',
#    'name': 'SOFT TEE - T-shirt imprimé - real navy blue',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '14,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'tom-tailor-denim-soft-tee-t-shirt-imprime-real-navy-blue-to721d0op-k11',
#    'media': [{'path': 'TO/72/1D/0O/PK/11/TO721D0OP-K11@14.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/72/1D/0O/PK/11/TO721D0OP-K11@15.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'TOM TAILOR DENIM',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI112O093-H11',
#    'name': 'SIGNAL D/MS/X - Baskets basses - guava ice/light aqua/hyper crimson/blue hero/cedar/black',
#    'price': {'original': '124,95\xa0€',
#     'promotional': '61,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-signal-dmsx-baskets-basses-ni112o093-h11',
#    'media': [{'path': 'NI/11/2O/09/3H/11/NI112O093-H11@9.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'NI/11/2O/09/3H/11/NI112O093-H11@19.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'DP511N08V-Q11',
#    'name': 'ASTRID HEEL ZIP - Boots à talons - black',
#    'price': {'original': '49,99\xa0€',
#     'promotional': '24,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'dorothy-perkins-astrid-heel-zip-boots-a-talons-black-dp511n08v-q11',
#    'media': [{'path': 'DP/51/1N/08/VQ/11/DP511N08V-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Dorothy Perkins',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI111A0D1-A11',
#    'name': 'Baskets basses - white/black',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '76,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-zoom-2k-baskets-basses-ni111a0d1-a11',
#    'media': [{'path': 'NI/11/1A/0D/1A/11/NI111A0D1-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'MIG21E01F-Q11',
#    'name': 'TRIM CROSS BACK CAMI 2 PACK - Débardeur - black/white',
#    'price': {'original': '37,99\xa0€',
#     'promotional': '18,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34', '36', '38', '40', '42'],
#    'url_key': 'missguided-tall-trim-cross-back-cami-2-pack-debardeur-blackwhite-mig21e01f-q11',
#    'media': [{'path': 'MI/G2/1E/01/FQ/11/MIG21E01F-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'MI/G2/1E/01/FQ/11/MIG21E01F-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Missguided Tall',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'},
#     {'key': 'assortmentArea', 'value': 'Grande', 'tracking_value': 'tall'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI121D0FO-Q11',
#    'name': 'AIR - T-shirt à manches longues - black',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '33,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-air-t-shirt-a-manches-longues-ni121d0fo-q11',
#    'media': [{'path': 'NI/12/1D/0F/OQ/11/NI121D0FO-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1D/0F/OQ/11/NI121D0FO-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'M4511X008-D11',
#    'name': 'Bottes de neige - silver',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35-38', '39-41', '42-44'],
#    'url_key': 'moon-boot-bottes-de-neige-silver-m4511x008-d11',
#    'media': [{'path': 'M4/51/1X/00/8D/11/M4511X008-D11@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Moon Boot',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI121U00L-Q11',
#    'name': 'FILL - Veste mi-saison - black/white',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '84,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-fill-veste-dhiver-blackwhite-ni121u00l-q11',
#    'media': [{'path': 'NI/12/1U/00/LQ/11/NI121U00L-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1U/00/LQ/11/NI121U00L-Q11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD111A0X1-A11',
#    'name': 'SUPERCOURT - Baskets basses - footwear white/true pink',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '53,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3'],
#    'url_key': 'adidas-originals-supercourt-baskets-basses-footwear-whitetrue-pink-ad111a0x1-a11',
#    'media': [{'path': 'AD/11/1A/0X/1A/11/AD111A0X1-A11@34.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD111A0Q7-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/gold metallic',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitegold-metallic-ad111a0q7-a11',
#    'media': [{'path': 'AD/11/1A/0Q/7A/11/AD111A0Q7-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VE121G0OG-Q11',
#    'name': 'VMRIA SHORT JACKET - Veste en similicuir - black',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '31,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'vero-moda-vmria-short-jacket-veste-en-similicuir-black-ve121g0og-q11',
#    'media': [{'path': 'VE/12/1G/0O/GQ/11/VE121G0OG-Q11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1G/0O/GQ/11/VE121G0OG-Q11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI111A0D1-A12',
#    'name': 'Baskets basses - sail/white/black',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-zoom-2k-baskets-basses-ni111a0d1-a12',
#    'media': [{'path': 'NI/11/1A/0D/1A/12/NI111A0D1-A12@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI111A0J3-Q11',
#    'name': 'AF1 SHADOW - Baskets basses - black/hyper crimson/cargo khaki',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '77,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-af1-shadow-baskets-basses-blackhyper-crimsoncargo-khaki-ni111a0j3-q11',
#    'media': [{'path': 'NI/11/1A/0J/3Q/11/NI111A0J3-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'JY121I0AZ-Q11',
#    'name': 'JDYLAVERNE STRUCTURE - Pullover - black',
#    'price': {'original': '19,99\xa0€',
#     'promotional': '10,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'jdy-jdylaverne-structure-pullover-jy121i0az-q11',
#    'media': [{'path': 'JY/12/1I/0A/ZQ/11/JY121I0AZ-Q11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'JY/12/1I/0A/ZQ/11/JY121I0AZ-Q11@14.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'JDY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD121D0LI-Q11',
#    'name': 'STRIPES TEE - T-shirt imprimé - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-tee-t-shirt-imprime-black-ad121d0li-q11',
#    'media': [{'path': 'AD/12/1D/0L/IQ/11/AD121D0LI-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1D/0L/IQ/11/AD121D0LI-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD115O03A-Q11',
#    'name': 'NIZZA - Baskets basses - core black/footwear white',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '34,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-nizza-baskets-basses-core-blackfootwear-white-ad115o03a-q11',
#    'media': [{'path': 'AD/11/5O/03/AQ/11/AD115O03A-Q11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PE621D06V-G11',
#    'name': 'T-shirt à manches longues - dark red',
#    'price': {'original': '20,95\xa0€',
#     'promotional': '17,75\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'petit-bateau-tee-shirt-t-shirt-a-manches-longues-pe621d06v-g11',
#    'media': [{'path': 'PE/62/1D/06/VG/11/PE621D06V-G11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'PE/62/1D/06/VG/11/PE621D06V-G11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Petit Bateau',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'OND21U019-K11',
#    'name': 'Manteau classique - night sky',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '34,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'only-tall-manteau-classique-night-sky-ond21u019-k11',
#    'media': [{'path': 'ON/D2/1U/01/9K/11/OND21U019-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ON/D2/1U/01/9K/11/OND21U019-K11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'ONLY Tall',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA221D03T-K11',
#    'name': 'ROUND NECK CLASSIC TEE - T-shirt basique - marine',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '39,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'lacoste-classic-tee-t-shirt-basique-la221d03t-k11',
#    'media': [{'path': 'LA/22/1D/03/TK/11/LA221D03T-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/1D/03/TK/11/LA221D03T-K11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AN611BA4P-K11',
#    'name': 'Escarpins à plateforme - dark blue',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '17,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40', '41'],
#    'url_key': 'anna-field-escarpins-compenses-dark-blue-an611ba4p-k11',
#    'media': [{'path': 'AN/61/1B/A4/PK/11/AN611BA4P-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LE221D05G-A12',
#    'name': 'THE PERFECT TEE - T-shirt imprimé - white/red',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '16,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'levisr-the-perfect-tee-t-shirt-imprime-le221d05g-a12',
#    'media': [{'path': 'LE/22/1D/05/GA/12/LE221D05G-A12@10.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1D/05/GA/12/LE221D05G-A12@11.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'V1021A0EB-M11',
#    'name': 'VISOFINA PANT - Pantalon classique - pine grove',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '27,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44', '46'],
#    'url_key': 'vila-visofina-pantalon-classique-v1021a0eb-m11',
#    'media': [{'path': 'V1/02/1A/0E/BM/11/V1021A0EB-M11@15.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'V1/02/1A/0E/BM/11/V1021A0EB-M11@13.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'FID21D00J-K11',
#    'name': 'ALLISON TEE - T-shirt imprimé - black iris/true red/bright white',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '22,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42'],
#    'url_key': 'fila-petite-allison-tee-t-shirt-imprime-black-iristrue-redbright-white-fid21d00j-k11',
#    'media': [{'path': 'FI/D2/1D/00/JK/11/FID21D00J-K11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'FI/D2/1D/00/JK/11/FID21D00J-K11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fila Petite',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'},
#     {'key': 'assortmentArea', 'value': 'Petite', 'tracking_value': 'petite'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TP721U071-J11',
#    'name': 'MONICA - Manteau classique - pink',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '49,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34', '36', '38', '40', '42', '44'],
#    'url_key': 'topshop-monica-manteau-classique-pink-tp721u071-j11',
#    'media': [{'path': 'TP/72/1U/07/1J/11/TP721U071-J11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TP/72/1U/07/1J/11/TP721U071-J11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Topshop',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ON321U0DU-K11',
#    'name': "ONLVIKKI QUILTED COAT - Veste d'hiver - night sky",
#    'price': {'original': '69,95\xa0€',
#     'promotional': '34,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'only-onlvikki-quilted-coat-veste-dhiver-night-sky-on321u0du-k11',
#    'media': [{'path': 'ON/32/1U/0D/UK/11/ON321U0DU-K11@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ON/32/1U/0D/UK/11/ON321U0DU-K11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'ONLY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'DP511A0GX-A11',
#    'name': 'ISABELLE TRAINER - Baskets basses - white',
#    'price': {'original': '32,99\xa0€',
#     'promotional': '16,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'dorothy-perkins-isabelle-trainer-baskets-basses-dp511a0gx-a11',
#    'media': [{'path': 'DP/51/1A/0G/XA/11/DP511A0GX-A11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Dorothy Perkins',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA211A08Q-F11',
#    'name': 'OLD SKOOL - Baskets basses - rose gold',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '71,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '36.5', '37', '38', '38.5', '39', '40', '40.5', '41', '42'],
#    'url_key': 'vans-old-skool-baskets-basses-va211a08q-f11',
#    'media': [{'path': 'VA/21/1A/08/QF/11/VA211A08Q-F11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PU115O050-A11',
#    'name': 'RALPH SAMPSON - Baskets basses - white',
#    'price': {'original': '80,00\xa0€',
#     'promotional': '52,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '47',
#     '48.5'],
#    'url_key': 'puma-ralph-sampson-baskets-basses-white-pu115o050-a11',
#    'media': [{'path': 'PU/11/5O/05/0A/11/PU115O050-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LE221D07K-A11',
#    'name': 'THE PERFECT TEE - T-shirt imprimé - hsmk dunsmuir fill white',
#    'price': {'original': '28,95\xa0€',
#     'promotional': '24,55\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'levisr-the-perfect-tee-t-shirt-imprime-le221d07k-a11',
#    'media': [{'path': 'LE/22/1D/07/KA/11/LE221D07K-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1D/07/KA/11/LE221D07K-A11@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'L4251D04S-O11',
#    'name': 'SUPER SMOOTH LOGO - Ceinture - field brown',
#    'price': {'original': '48,95\xa0€',
#     'promotional': '29,35\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'lauren-ralph-lauren-super-smooth-logo-ceinture-l4251d04s-o11',
#    'media': [{'path': 'L4/25/1D/04/SO/11/L4251D04S-O11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'L4/25/1D/04/SO/11/L4251D04S-O11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lauren Ralph Lauren',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NI111A0IU-Q11',
#    'name': 'RYZ  - Baskets basses - black/white',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '76,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5'],
#    'url_key': 'nike-sportswear-uptear-baskets-basses-ni111a0iu-q11',
#    'media': [{'path': 'NI/11/1A/0I/UQ/11/NI111A0IU-Q11@3.jpg',
#      'role': 'DEFAULT',
# ...
#      'family_id': 'OB00',
#      'is_family': False},
#     {'key': 'OD1', 'label': 'ODLO', 'is_family': False},
#     {'key': 'OF00', 'label': 'Office', 'is_family': True},
#     {'key': 'OF2', 'label': 'Office', 'family_id': 'OF00', 'is_family': False},
#     {'key': 'OF4',
#      'label': 'Office Wide Fit',
#      'family_id': 'OF00',
#      'is_family': False},
#     {'key': 'OH0', 'label': 'ohma!', 'is_family': False},
#     ...],
#    'family_key': 'brand_families'},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4.49,
#     'max': 1559.95,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Soldes',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les Promos'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'OTHER', 'label': 'Autres matières'},
#     {'key': 'CASHMERE', 'label': 'Cachemire'},
#     {'key': 'CAOUTCHOUC', 'label': 'Caoutchouc'},
#     {'key': 'COTTON', 'label': 'Coton'},
#     {'key': 'CROCHETED', 'label': 'Crocheté'},
#     {'key': 'LEATHER', 'label': 'Cuir'},
#     {'key': 'CORD', 'label': 'Côtelé'},
#     {'key': 'DENIM', 'label': 'Denim'},
#     {'key': 'LACE', 'label': 'Dentelle'},
#     {'key': 'FELT', 'label': 'Feutre'},
#     {'key': 'FLANELETTE', 'label': 'Flanelle chaude'},
#     {'key': 'HARDSHELL', 'label': 'Hardshell'},
#     {'key': 'IMITATION_LEATHER', 'label': 'Imitation cuir'},
#     {'key': 'JERSEY', 'label': 'Jersey'},
#     {'key': 'WOOL', 'label': 'Laine'},
#     {'key': 'LINEN', 'label': 'Lin'},
#     {'key': 'MESH', 'label': 'Mesh'},
#     {'key': 'FEATHERS', 'label': 'Plume'},
#     {'key': 'FLEECE', 'label': 'Polaire'},
#     {'key': 'POLYESTER', 'label': 'Polyester'},
#     {'key': 'SATIN', 'label': 'Satin'},
#     {'key': 'SOFTSHELL', 'label': 'Softshell'},
#     {'key': 'SILK', 'label': 'Soie'},
#     {'key': 'RIB', 'label': 'Strié'},
#     {'key': 'SWEAT', 'label': 'Sweat'},
#     {'key': 'SYNTHETIC', 'label': 'Synthétique'},
#     {'key': 'TEXTILE', 'label': 'Textile'},
#     {'key': 'BRAIDED', 'label': 'tressé'},
#     {'key': 'VARNISH', 'label': 'Verni'},
#     {'key': 'VISCOSE', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}],
#    'group_id': 'sustainable'},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'STRIPED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'POLKA_DOT', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'PETITE', 'label': 'Petite'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'fr_aw19_fresh_days_2019_49', 'label': '-20% EXTRA'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'vegan',
#    'label': 'Végane',
#    'url_key': 'vegan',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Végane'}],
#    'group_id': 'vegan'}],
#  'total_article_count': 115497,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promos',
#    'id': '8803',
#    'url_key': 'promo-femme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-femme/',
#    'children': [{'label': 'Vêtements',
#      'id': '8838',
#      'url_key': 'promo-mode-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-femme/',
#      'children': [],
#      'article_count': 72275},
#     {'label': 'Chaussures',
#      'id': '8804',
#      'url_key': 'promo-chaussures-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-femme/',
#      'children': [],
#      'article_count': 29065},
#     {'label': 'Sacs et accessoires',
#      'id': '8860',
#      'url_key': 'promo-accessoires-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-femme/',
#      'children': [],
#      'article_count': 12863},
#     {'label': 'Lingerie',
#      'id': '8850',
#      'url_key': 'promo-lingerie-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-lingerie-femme/',
#      'children': [],
#      'article_count': 6227},
#     {'label': 'Luxe',
#      'id': '13429',
#      'url_key': 'promo-luxe-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-femme/',
#      'children': [],
#      'article_count': 7369},
#     {'label': 'Sport',
#      'id': '13286',
#      'url_key': 'promo-sport-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-femme/',
#      'children': [],
#      'article_count': 7209},
#     {'label': 'Beauté',
#      'id': '13478',
#      'url_key': 'beaute-femme-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-femme-promo/',
#      'children': [],
#      'article_count': 1151}],
#    'article_count': 115499}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Femme',
#      'url_key': 'femme',
#      'full_url': '/femme/'},
#     {'label': 'Promos',
#      'url_key': 'promo-femme',
#      'full_url': '/promo-femme/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-femme',
#       'url_key': 'promo-femme',
#       'label': 'Promos',
#       'seo_label': 'Promotions femme',
#       'reset_url': '/',
#       'id': '8803'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-femme/',
#   'reset_url': '/promo-femme/',
#   'app_url': '?urlKey=promo-femme&order=popularity&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-femme',
#     'url_key': 'promo-femme',
#     'label': 'Promos',
#     'seo_label': 'Promotions femme',
#     'reset_url': '/',
#     'id': '8803'}]},
#  'selectedFilters': {'categories': ['promo-femme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': 'Faire du shopping sans culpabiliser ? Avec nos promos pour femme, c’est possible ! Offrez-vous les incontournables de cette saison tels que le bomber XXL ou les loafers à prix réduit. Mais attention, ils partent vite !',
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/428ac29a-26f5-4946-aded-b2107d25d8b9/629d2961-0664-4adb-888e-9ad507ed362f/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=b7b4e5d2-e4a2-4235-ab0e-8d20d8ed65ea&timeUnit=null&timeUnitCount=null&uuid=12e39c4a-5eae-4860-ae5c-e432fa38777f&bid=null&requestId=e49e2a37-7613-4db4-9c88-4a4ceb6997bf&s=72F9A264F41D5AC33C1EDFD2113E976C'],
#    'images': [{'aspect_ratio': None,
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/3200/549/3500/spp-media-p1/8ed70eb91494454fb50c43eaa45e2e2a/217af45f5f5f46bb8f1cf36a73d444e5.jpeg',
#      'image_width': None},
#     {'aspect_ratio': None,
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/480/555/960/819/750/spp-media-p1/67c552c0d4bd41ebb242fd8a8fd5a87f/4f4550cdb7994842b0acdb1783e7c298.jpeg',
#      'image_width': None}],
#    'creative_id': 'b7b4e5d2-e4a2-4235-ab0e-8d20d8ed65ea',
#    'campaign_id': '428ac29a-26f5-4946-aded-b2107d25d8b9',
#    'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#    'campaign_source_id': 'RQsmB4tXTAC',
#    'text_fields': {'cta': "J'en profite",
#     'bg_color': '#940000',
#     'legal_claim': "*Offre valable jusqu'au 17/12/2019 à 23h59 sur les articles soldés et les prix minis, à partir de 90€ d'achat.",
#     'voucher_code': 'STAYFRESH',
#     'title': "JUSQU'À -50% ET -20% EXTRA",
#     'type': 'sales',
#     'sales_template': 'Voucher',
#     'byline': 'Juste à temps pour Noël ⏰',
#     'voucher_label': 'Code promo*'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#       'brand_code': '-1',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': 'VD0aVZIXyedwMkcN',
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'RQsmB4tXTAC',
#       'request_id': 'e49e2a37-7613-4db4-9c88-4a4ceb6997bf',
#       'campaign_id': '428ac29a-26f5-4946-aded-b2107d25d8b9',
#       'creative_id': 'b7b4e5d2-e4a2-4235-ab0e-8d20d8ed65ea'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'brand_code': '-1',
#        'adId': 'i00jHjcaTXq',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'VD0aVZIXyedwMkcN',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': 'e49e2a37-7613-4db4-9c88-4a4ceb6997bf',
#        'campaign_id': '428ac29a-26f5-4946-aded-b2107d25d8b9',
#        'creative_id': 'b7b4e5d2-e4a2-4235-ab0e-8d20d8ed65ea'},
#       'dimension74': {'adId': 'i00jHjcaTXq'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'brand_code': '-1',
#        'adId': 'i00jHjcaTXq',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'VD0aVZIXyedwMkcN',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': 'e49e2a37-7613-4db4-9c88-4a4ceb6997bf',
#        'campaign_id': '428ac29a-26f5-4946-aded-b2107d25d8b9',
#        'creative_id': 'b7b4e5d2-e4a2-4235-ab0e-8d20d8ed65ea'},
#       'dimension74': {'adId': 'i00jHjcaTXq'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/428ac29a-26f5-4946-aded-b2107d25d8b9/629d2961-0664-4adb-888e-9ad507ed362f/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=b7b4e5d2-e4a2-4235-ab0e-8d20d8ed65ea&timeUnit=null&timeUnitCount=null&uuid=876da994-d5a0-4767-a133-39cb02afb896&bid=null&requestId=e49e2a37-7613-4db4-9c88-4a4ceb6997bf&s=849C2DFE40A484C1A9E6F6244BECEE54'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'VD0aVZIXyedwMkcN',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'campaign_id': '428ac29a-26f5-4946-aded-b2107d25d8b9',
#      'creative_id': 'b7b4e5d2-e4a2-4235-ab0e-8d20d8ed65ea',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'brand_code': '-1',
#      'adId': 'i00jHjcaTXq',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': 'VD0aVZIXyedwMkcN',
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'request_id': 'e49e2a37-7613-4db4-9c88-4a4ceb6997bf',
#      'campaign_id': '428ac29a-26f5-4946-aded-b2107d25d8b9',
#      'creative_id': 'b7b4e5d2-e4a2-4235-ab0e-8d20d8ed65ea'}},
#    'click_url': 'https://www.zalando.fr/promo-femme/?camp=fr_aw19_fresh_days_2019_49&sale=true'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)

# %%
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   5VA51D009-Q11                             LADY - Ceinture - nero
# 1   VA215B000-Q12            OLD SKOOL - Chaussures de skate - black
# 2   UG111X03C-Q11        CLASSIC MINI LOGO - Bottes de neige - black
# 3   NI114D0CK-Q11                             Baskets basses - black
# 4   NI111A0IT-A11  TEKNO  - Baskets basses - white/metallic silve...
# ..            ...                                                ...
# 79  V1021E0ZZ-K11           VIDATE - Blouse - navy blazer/pine grove
# 80  VA215N01P-K11  SK8 REISSUE SAVE OUR PLANET - Baskets montante...
# 81  LA211A09O-A11                LEROND CAW - Baskets basses - white
# 82  JY121G019-Q11  JDYNEW BRIGHTON SPRING COAT - Manteau court - ...
# 83  PU111A094-Q11                CALI - Baskets basses - black/white
#
#                                                 sizes  \
# 0                                           [S, M, L]
# 1   [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# 2                        [37, 38, 39, 40, 41, 42, 43]
# 3                  [35.5, 36, 36.5, 37.5, 38, 39, 40]
# 4   [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# ..                                                ...
# 79                           [36, 38, 40, 42, 44, 46]
# 80  [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# 81  [35.5, 36, 37, 37.5, 38, 39, 39.5, 40, 40.5, 4...
# 82                                  [XS, S, M, L, XL]
# 83                   [36, 37, 37.5, 38, 38.5, 39, 40]
#
#                                               url_key  \
# 0   valentino-by-mario-valentino-lady-ceinture-ner...
# 1         vans-old-skool-baskets-basses-va215b000-q12
# 2   ugg-classic-mini-logo-bottes-de-neige-black-ug...
# 3   nike-sportswear-court-borough-baskets-basses-n...
# 4   nike-sportswear-tekno-baskets-basses-ni111a0it...
# ..                                                ...
# 79  vila-vidate-t-shirt-a-manches-longues-navy-bla...
# 80  vans-sk8-reissue-save-our-planet-baskets-monta...
# 81  lacoste-lerond-caw-baskets-basses-white-la211a...
# 82  jdy-jdynew-brighton-spring-coat-manteau-classi...
# 83  puma-cali-baskets-basses-blackwhite-pu111a094-q11
#
#                                                 media  \
# 0   [{'path': '5V/A5/1D/00/9Q/11/5VA51D009-Q11@6.j...
# 1   [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12....
# 2   [{'path': 'UG/11/1X/03/CQ/11/UG111X03C-Q11@8.j...
# 3   [{'path': 'NI/11/4D/0C/KQ/11/NI114D0CK-Q11@5.j...
# 4   [{'path': 'NI/11/1A/0I/TA/11/NI111A0IT-A11@12....
# ..                                                ...
# 79  [{'path': 'V1/02/1E/0Z/ZK/11/V1021E0ZZ-K11@10....
# 80  [{'path': 'VA/21/5N/01/PK/11/VA215N01P-K11@10....
# 81  [{'path': 'LA/21/1A/09/OA/11/LA211A09O-A11@13....
# 82  [{'path': 'JY/12/1G/01/9Q/11/JY121G019-Q11@15....
# 83  [{'path': 'PU/11/1A/09/4Q/11/PU111A094-Q11@3.j...
#
#                       brand_name  is_premium family_articles  \
# 0   Valentino by Mario Valentino       False              []
# 1                           Vans       False              []
# 2                            UGG       False              []
# 3                Nike Sportswear       False              []
# 4                Nike Sportswear       False              []
# ..                           ...         ...             ...
# 79                          Vila       False              []
# 80                          Vans       False              []
# 81                       Lacoste       False              []
# 82                           JDY       False              []
# 83                          Puma       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': '-20% EXTRA', 't...   accessoires
# 1   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 2   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 3   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 4   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 80  [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 81  [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 82  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 83  [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
#
#    delivery_promises price.original price.promotional  \
# 0                 []        34,99 €           27,99 €
# 1                 []        74,95 €           67,45 €
# 2                 []       169,95 €          135,95 €
# 3                 []        44,95 €           35,95 €
# 4                 []        99,95 €           59,95 €
# ..               ...            ...               ...
# 79                []        29,95 €           14,99 €
# 80                []        89,95 €           53,95 €
# 81                []        84,95 €           59,45 €
# 82                []        39,99 €           31,99 €
# 83                []        84,95 €           67,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                         True                                False
# 4                         True                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                        True                                False
# 81                        True                                False
# 82                       False                                False
# 83                        True                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                     True
# ..                                     ...
# 79                                   False
# 80                                    True
# 81                                    True
# 82                                   False
# 83                                    True
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#                                               outfits
# 0                                                 NaN
# 1   [{'id': 'GS2rkdweTwu', 'url_key': '/outfits/GS...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
# [84 rows x 18 columns]

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']
total_pages
# Out:
# 892

# %%
df=pd.DataFrame()
for i in range(total_pages):
    k=total_pages*i
    url = f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
    response = requests.get(url, headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
# Out:
# /home/almsasantos/miniconda3/envs/data_env/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f09a1fd6b14a> in <module>
#       6     results = response.json()
#       7     flattened_data = json_normalize(results)
# ----> 8     flattened_data1 = json_normalize(flattened_data.articles[0])
#       9     flattened_data1=flattened_data1.set_index('sku')
#      10     df = df.append(flattened_data1)
#
# ~/miniconda3/envs/data_env/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'articles'

# %%
display(df)

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
